# %%
library(tidyr)
library(tidyverse) 
library(knitr)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ dplyr   1.0.10
# ✔ tibble  3.1.8      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ✔ purrr   0.3.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# # Data Cleaning/Import

# %%
# Read in CSV file
test_data <- read.csv("R_test.csv")

# Remove second row so column names are preserved
test_data <- test_data[-c(1),]

# Change column names
colnames(test_data)[1] <- "Record_ID"
colnames(test_data)[2] <- "email"

# Convert "Unchecked" and empty values to NA in all columns
checked_columns <- colnames(test_data)[-c(1, 2)]  # Get column names excluding Record_ID and email

for (col in checked_columns) {
  test_data[[col]] <- ifelse(test_data[[col]] %in% c("Unchecked", ""), NA, test_data[[col]])
}

# Remove rows with all missing values - remove rows where all values are NA except for "Record_ID", "email", and "Q219" columns
test_data <- test_data[rowSums(is.na(test_data[, 3:844])) != (844 - 3 + 1), ]

# Find rows with duplicate email
duplicate_data <- test_data[duplicated(test_data$email) | duplicated(test_data$email, fromLast = TRUE), ]

# Merge rows with duplicate email, keeping only non-missing values and updating Record_ID
merged_data <- duplicate_data %>%
  group_by(email) %>%
  summarize(across(everything(), ~ ifelse(all(is.na(.)), NA, first(na.omit(.)))), .groups = "drop")

# Combine non-duplicate rows with merged rows
final_data <- test_data %>%
  group_by(email) %>%
  summarize(across(everything(), ~ ifelse(all(is.na(.)), NA, first(na.omit(.)))), .groups = "drop")

# Convert "Checked" to 1
final_data[] <- lapply(final_data, function(x) ifelse(x == "Checked", 1, x))

# %%
final_data
# Out:
#      email                             Record_ID
# 1                                      1136
# 2    19tyler@gmail.com                 422
# 3    3sollenberger@gmail.com           1294
# 4    6ap464zdb@mozmail.com             687
# 5    aabundiz@hyacinth.org             1519
# 6    aadegbulugbe@totalhealthcare.org  222
# 7    aalbior@bach.health               1550
# 8    aalcanta@conemaugh.org            1385
# 9    abby.hinz@eauclairecounty.gov     258
# 10   abergman@cmhcm.org                1123
# 11   abilly@iuhealth.org               774
# 12   abmontalvo@sbchc.net              1612
# 13   aboatwright@sfcommunityhealth.org 200
# 14   acampos@familycenters.org         83
# 15   acastel@gwu.edu                   391
# 16   aclarke@riversidehealth.org       1008
# 17   Adam.lake@pennmedicine.upenn.edu  901
# 18   addie.zuniga@dph.ga.gov           54
# 19   adelaidamartin@gmail.com          601
# 20   adickerson@yss.org                754
# 21   Admin@connectdcare.com            123
# 22   Aevans@tulane.edu                 473
# 23   aflores@hyacinth.org              1416
# 24   afort1@iuhealth.org               827
# 25   agalarza@cookcountyhhs.org        47
# 26   agannett@hamiltonhealthcenter.com 1234
# 27   Agirmay@kintegra.org              388
# 28   aglorioso@daphealth.org           248
# 29   agnes.santiago-cotto@va.gov       930
# 30   agonzalez@centrocultural.org      6
# ⋮    ⋮                                 ⋮
# 1085 wgarcia@hyacinth.org              808
# 1086 wgrullon@ACRHealth.org            29
# 1087 whitebreads@thewrightcenter.org   61
# 1088 wilfred@wavesahead.org            1062
# 1089 wjenkins@aidsdelaware.org         196
# 1090 wkomis@chicagofamilyhealth.org    386
# 1091 wlaabadawy320@yahoo.com           1283
# 1092 wmote@lrmcenter.com               464
# 1093 wncap@wncap.org                   226
# 1094 wphillips@centerlb.org            651
# 1095 Wrha238@uky.edu                   660
# 1096 wtyx01@gmail.com                  1266
# 1097 Wynnett.Stewart@ynhh.org          207
# 1098 xivcam@gmail.com                  841
# 1099 yamiller83@gmail.com              428
# 1100 yavonne.dubose@dc.gov             555
# 1101 ybell@aboundingprosperity.org     169
# 1102 yesenia.cornejo@wattshealth.org   336
# 1103 yolanda.scott@dc.gov              1356
# 1104 ypb7352@gmail.com                 1135
# 1105 Ypuerto@med.miami.edu             673
# 1106 yudenia@iajems.org                1585
# 1107 yvonnel@cccswla.org               1491
# 1108 zbird@centeronhalsted.org         837
# 1109 zee.stjames@gmail.com             872
# 1110 zfd2yy@uvahealth.org              240
# 1111 zhennessey@gmail.com              1392
# 1112 zmuneton@browardhealth.org        497
# 1113 zpenny@obfh.org                   600
# 1114 zulinew@bebashi.orgrg             1059
#      Q1                                            Q2
# 1    LBGTQ Health Center/Community Center          NA
# 2    Non-profit organization                       NA
# 3    Non-profit organization                       NA
# 4    Community Based Organization (CBO)            NA
# 5    Community Based Organization (CBO)            NA
# 6    Federally Qualified Health Center (FQHC)      NA
# 7    Federally Qualified Health Center (FQHC)      NA
# 8    AIDS Service Organization (ASO)               NA
# 9    Health department clinic/public health clinic NA
# 10   Government entity (Local, State, Federal)     NA
# 11   AIDS Service Organization (ASO)               NA
# 12   Federally Qualified Health Center (FQHC)      NA
# 13   Health department (non-clinic)                NA
# 14   AIDS Service Organization (ASO)               NA
# 15   Health department clinic/public health clinic NA
# 16   AIDS Service Organization (ASO)               NA
# 17   Academic hospital/clinic setting              NA
# 18   Health department (non-clinic)                NA
# 19   Non-profit organization                       NA
# 20   Non-profit organization                       NA
# 21   Private practice                              NA
# 22   Academic hospital/clinic setting              NA
# 23   Non-profit organization                       NA
# 24   AIDS Service Organization (ASO)               NA
# 25   Health department clinic/public health clinic NA
# 26   Federally Qualified Health Center (FQHC)      NA
# 27   Federally Qualified Health Center (FQHC)      NA
# 28   Federally Qualified Health Center (FQHC)      NA
# 29   Government entity (Local, State, Federal)     NA
# 30   Community Based Organization (CBO)            NA
# ⋮    ⋮                                             ⋮
# 1085 LBGTQ Health Center/Community Center          NA
# 1086 Community Based Organization (CBO)            NA
# 1087 Federally Qualified Health Center (FQHC)      NA
# 1088 LBGTQ Health Center/Community Center          NA
# 1089 AIDS Service Organization (ASO)               NA
# 1090 Federally Qualified Health Center (FQHC)      NA
# 1091 Other                                         king khalid
# 1092 Federally Qualified Health Center (FQHC)      NA
# 1093 AIDS Service Organization (ASO)               NA
# 1094 LBGTQ Health Center/Community Center          NA
# 1095 Other                                         HIV/HepC health education
# 1096 Community Based Organization (CBO)            NA
# 1097 Academic hospital/clinic setting              NA
# 1098 Government entity (Local, State, Federal)     NA
# 1099 Non-profit organization                       NA
# 1100 Government entity (Local, State, Federal)     NA
# 1101 Community Based Organization (CBO)            NA
# 1102 Community Based Organization (CBO)            NA
# 1103 Government entity (Local, State, Federal)     NA
# 1104 LBGTQ Health Center/Community Center          NA
# 1105 Private hospital/clinic setting               NA
# 1106 Non-profit organization                       NA
# 1107 Community Based Organization (CBO)            NA
# 1108 LBGTQ Health Center/Community Center          NA
# 1109 Advocacy organization                         NA
# 1110 Academic hospital/clinic setting              NA
# 1111 Non-profit organization                       NA
# 1112 Non-profit organization                       NA
# 1113 Federally Qualified Health Center (FQHC)      NA
# 1114 AIDS Service Organization (ASO)               NA
#      Q3                   Q4    Q5       Q6  Q7 Q8 ⋯
# 1    Connecticut          6511  Urban    Yes  1  1 ⋯
# 2    District of Columbia 20005 Urban    No   1 NA ⋯
# 3    Pennsylvania         15222 Urban    No   1  1 ⋯
# 4    New York             14527 Rural    No   1  1 ⋯
# 5    New Jersey           7060  Suburban No  NA NA ⋯
# 6    Maryland             21223 Urban    Yes  1  1 ⋯
# 7    California           94538 Suburban No  NA NA ⋯
# 8    Pennsylvania         15905 Rural    No   1  1 ⋯
# 9    Wisconsin            54703 Urban    Yes  1 NA ⋯
# 10   Michigan             48858 Suburban No   1  1 ⋯
# 11   Indiana              47909 Urban    No   1  1 ⋯
# 12   Texas                77055 Urban    No   1  1 ⋯
# 13   California           94102 Urban    No   1  1 ⋯
# 14   Connecticut          6902  Suburban No  NA NA ⋯
# 15   District of Columbia 20002 Urban    No   1  1 ⋯
# 16   New York             10703 Urban    Yes  1  1 ⋯
# 17   Pennsylvania         17602 Suburban Yes  1  1 ⋯
# 18   Georgia              30008 Suburban Yes  1 NA ⋯
# 19   District of Columbia 20017 Urban    No   1  1 ⋯
# 20   Iowa                 50010 Suburban No   1 NA ⋯
# 21   Delaware             19901 Rural    No   1  1 ⋯
# 22   Louisiana            71301 Suburban Yes  1  1 ⋯
# 23   New Jersey           7306  Urban    No  NA NA ⋯
# 24   Indiana              47401 Suburban No   1  1 ⋯
# 25   Illinois             60612 Urban    Yes  1  1 ⋯
# 26   Pennsylvania         17104 Urban    Yes  1  1 ⋯
# 27   North Carolina       28052 Suburban Yes  1  1 ⋯
# 28   California           92262 Urban    Yes  1  1 ⋯
# 29   Puerto Rico          921   Urban    Yes NA NA ⋯
# 30   Oregon               97113 Suburban No  NA NA ⋯
# ⋮    ⋮                    ⋮     ⋮        ⋮   ⋮  ⋮  ⋱
# 1085 New Jersey           7501  Urban    No  NA NA ⋯
# 1086 New York             13501 Rural    No   1 NA ⋯
# 1087 Pennsylvania         18505 Urban    Yes  1  1 ⋯
# 1088 Puerto Rico          921   Suburban No  NA NA ⋯
# 1089 Delaware             19801 Urban    No   1  1 ⋯
# 1090 Illinois             60617 Urban    No   1  1 ⋯
# 1091 Illinois             61411 Suburban Yes NA NA ⋯
# 1092 South Carolina       29566 Urban    Yes  1  1 ⋯
# 1093 North Carolina       28803 Urban    No  NA NA ⋯
# 1094 California           90814 Urban    No   1  1 ⋯
# 1095 Kentucky             40258 Suburban Yes  1  1 ⋯
# 1096 California           90012 Rural    Yes NA  1 ⋯
# 1097 Connecticut          6510  Urban    Yes  1  1 ⋯
# 1098 Oregon               97232 Urban    No  NA NA ⋯
# 1099 Puerto Rico          612   Urban    No   1  1 ⋯
# 1100 District of Columbia 20003 Urban    No  NA NA ⋯
# 1101 Texas                75215 Urban    Yes  1  1 ⋯
# 1102 California           90002 Urban    No   1  1 ⋯
# 1103 District of Columbia 20002 Urban    No   1  1 ⋯
# 1104 Hawaii               96813 Urban    No   1  1 ⋯
# 1105 Florida              33136 Urban    Yes  1  1 ⋯
# 1106 Mississippi          39202 Rural    No  NA NA ⋯
# 1107 Louisiana            70601 Rural    Yes  1  1 ⋯
# 1108 Illinois             60613 Urban    No   1  1 ⋯
# 1109 Michigan             48202 Urban    No  NA NA ⋯
# 1110 Virginia             22903 Suburban Yes  1  1 ⋯
# 1111 New York             10003 Urban    No   1  1 ⋯
# 1112 Florida              33316 Urban    Yes  1 NA ⋯
# 1113 Florida              32805 Urban    Yes  1  1 ⋯
# 1114 Pennsylvania         19123 Rural    No   1  1 ⋯
#      Q810
# 1    NA
# 2    fear of how far laws will go  and stigmatizingp -
# 3    NA
# 4    NA
# 5    NA
# 6    NA
# 7    NA
# 8    NA
# 9    NA
# 10   Any policy that impacts the queer community, will impact those individuals in our agency.
# 11   NA
# 12   NA
# 13   NA
# 14   NA
# 15   NA
# 16   NA
# 17   Worse mental health in trans community
# 18   NA
# 19   NA
# 20   suicide rate is going to increase
# 21   Yes
# 22   NA
# 23   NA
# 24   It deters them from being out and honest to their healthcare providers
# 25   NA
# 26   NA
# 27   NA
# 28   NA
# 29   NA
# 30   NA
# ⋮    ⋮
# 1085 NA
# 1086 NA
# 1087 NA
# 1088 NA
# 1089 NA
# 1090 NA
# 1091 NA
# 1092 NA
# 1093 They are mean spirited laws.
# 1094 NA
# 1095 NA
# 1096 NA
# 1097 NA
# 1098 NA
# 1099 they feel worried that they may soon not have access to care.
# 1100 NA
# 1101 NA
# 1102 NA
# 1103 NA
# 1104 It will expand services
# 1105 NA
# 1106 NA
# 1107 NA
# 1108 NA
# 1109 NA
# 1110 NA
# 1111 They discourage providers from offering affirming care
# 1112 clients are afraid.
# 1113 NA
# 1114 NA
#      Q811
# 1    NA
# 2    Unsure
# 3    Yes
# 4    NA
# 5    Unsure
# 6    Yes
# 7    Yes
# 8    NA
# 9    Yes
# 10   Yes
# 11   Yes
# 12   Unsure
# 13   NA
# 14   Yes
# 15   Yes
# 16   Unsure
# 17   Yes
# 18   Yes
# 19   Yes
# 20   Yes
# 21   Yes
# 22   Unsure
# 23   Unsure
# 24   Yes
# 25   Unsure
# 26   Yes
# 27   Yes
# 28   Yes
# 29   Unsure
# 30   Unsure
# ⋮    ⋮
# 1085 NA
# 1086 Yes
# 1087 No
# 1088 Yes
# 1089 Unsure
# 1090 Unsure
# 1091 No
# 1092 Yes
# 1093 Unsure
# 1094 NA
# 1095 No
# 1096 Yes
# 1097 Unsure
# 1098 Yes
# 1099 Yes
# 1100 NA
# 1101 NA
# 1102 Unsure
# 1103 NA
# 1104 Yes
# 1105 NA
# 1106 Unsure
# 1107 No
# 1108 Yes
# 1109 Yes
# 1110 Unsure
# 1111 Yes
# 1112 Yes
# 1113 NA
# 1114 Unsure
#      Q812
# 1    NA
# 2    fear
# 3    NA
# 4    NA
# 5    NA
# 6    increases stress due to more stigma and discrimination
# 7    NA
# 8    NA
# 9    Feel less support for the general community/society
# 10   Increased crises with trans clients due to anti-trans laws.
# 11   NA
# 12   NA
# 13   NA
# 14   Fear of lack of care
# 15   No one has explicitly said it but I would image it has
# 16   NA
# 17   Not sure where to start
# 18   NA
# 19   Patient are afraid of getting hurt
# 20   NA
# 21   It has
# 22   NA
# 23   NA
# 24   It increases stress and danger, thereby increasing the health risks associated with long-term stress trauma
# 25   NA
# 26   Our trans patients consistently worry about the state of politics and how it impacts their lives and humanity
# 27   It is not right to deny healthcare because of their gender
# 28   NA
# 29   NA
# 30   NA
# ⋮    ⋮
# 1085 NA
# 1086 NA
# 1087 I have not heard anything
# 1088 Increase utilization of support groups and services due to anxiety and depression by patients
# 1089 NA
# 1090 Illinois has some of the most progressive gender affirming care policies, but the national negative anti-trans legislation likely still has an impact.
# 1091 NA
# 1092 Many are afraid to talk about their gender now.
# 1093 Probably has, but don't know specific thoughts of people.
# 1094 NA
# 1095 N/a
# 1096 NA
# 1097 I know that discrimination of any kind whether direct or indirect negatively impacts mental health of the affected community
# 1098 it's inflicting trauma
# 1099 thay are even scared of traveling and been in a state that could kill them
# 1100 NA
# 1101 NA
# 1102 NA
# 1103 NA
# 1104 It has!
# 1105 NA
# 1106 NA
# 1107 The agency provides gender-affirming care to youth so there are no issues in this area.
# 1108 Even being in a predominant liberal state like IL, the trans community is still facing mental health crisis for the fear that their rights here could go away if the offensive laws from FL move up north.
# 1109 minority stress is only compounded when anti trans messages increase. People are on eddge, worrying about their safety, and may delay or stop gender affirming care.
# 1110 NA
# 1111 Discrimination produces chronic, toxic stress
# 1112 increase stigma
# 1113 NA
# 1114 NA
#      Q813 Q814 Q815 Q816
# 1    NA   NA   NA   NA
# 2    No   NA   Yes  Yes
# 3    No   NA   No   NA
# 4    NA   NA   NA   NA
# 5    No   NA   No   NA
# 6    No   NA   No   NA
# 7    No   NA   No   NA
# 8    NA   NA   NA   NA
# 9    No   NA   No   NA
# 10   No   NA   NA   NA
# 11   No   NA   No   NA
# 12   No   NA   No   NA
# 13   NA   NA   NA   NA
# 14   No   NA   No   NA
# 15   No   NA   Yes  Yes
# 16   No   NA   No   NA
# 17   No   NA   Yes  Yes
# 18   No   NA   NA   NA
# 19   No   NA   No   NA
# 20   No   NA   Yes  Yes
# 21   Yes  NA   Yes  Yes
# 22   No   NA   No   NA
# 23   No   NA   NA   NA
# 24   No   NA   Yes  Yes
# 25   No   NA   No   NA
# 26   No   NA   Yes  Yes
# 27   No   NA   No   NA
# 28   No   NA   No   NA
# 29   No   NA   No   NA
# 30   No   NA   NA   NA
# ⋮    ⋮    ⋮    ⋮    ⋮
# 1085 NA   NA   NA   NA
# 1086 No   NA   No   NA
# 1087 No   NA   No   NA
# 1088 No   NA   No   NA
# 1089 No   NA   NA   NA
# 1090 No   NA   No   NA
# 1091 No   NA   NA   NA
# 1092 No   NA   No   NA
# 1093 No   NA   Yes  Yes
# 1094 NA   NA   NA   NA
# 1095 No   NA   No   NA
# 1096 No   NA   NA   NA
# 1097 No   NA   No   NA
# 1098 No   NA   No   NA
# 1099 No   NA   NA   NA
# 1100 NA   NA   NA   NA
# 1101 NA   NA   NA   NA
# 1102 No   NA   No   NA
# 1103 NA   NA   NA   NA
# 1104 No   NA   No   NA
# 1105 NA   NA   NA   NA
# 1106 No   NA   NA   NA
# 1107 No   NA   No   NA
# 1108 No   NA   No   NA
# 1109 No   NA   Yes  Yes
# 1110 No   NA   NA   NA
# 1111 No   NA   NA   NA
# 1112 No   NA   No   NA
# 1113 NA   NA   NA   NA
# 1114 No   NA   No   NA
#      Q817
# 1    NA
# 2    gov refuses to use evidenced based data
# 3    NA
# 4    NA
# 5    NA
# 6    NA
# 7    NA
# 8    NA
# 9    NA
# 10   NA
# 11   NA
# 12   NA
# 13   NA
# 14   NA
# 15   being able to access SSPs likely reduces their HIV risk
# 16   NA
# 17   I haven't been able to provide colocated services or openly partner with the harm reduction coalition due to my health system's concern over legality
# 18   NA
# 19   NA
# 20   possession of fentynal strip are illegal
# 21   It does
# 22   NA
# 23   NA
# ...
# 1091 NA
# 1092 NA
# 1093 People are at a high level of stress.  Hope suicides don't increase.  Wish we could get rid of guns.
# 1094 NA
# 1095 No
# 1096 NA
# 1097 NA
# 1098 NA
# 1099 NA
# 1100 NA
# 1101 NA
# 1102 NA
# 1103 NA
# 1104 NA
# 1105 NA
# 1106 NA
# 1107 This work is challenging and tedious but worth it!
# 1108 NA
# 1109 As a program that deals with key populations (sex workers), we have countless barriers to entering this field. Our employees often need more support than we are able to provide. Peer services training does not account for the many intersecting barriers that people who do sex work encounter when trying to achieve employment & learn new skills. There is so much red tape and beuaracracy in the 'legacy' HIV programs that many are not open to grassroots groups such as ourselves. They support criminalization, and spread myths about paraphernalia litter. They want to gatekeep these careers from us.
# 1110 NA
# 1111 NA
# 1112 no
# 1113 NA
# 1114 NA
#      Q819
# 1    Incomplete
# 2    Complete
# 3    Complete
# 4    Incomplete
# 5    Complete
# 6    Complete
# 7    Complete
# 8    Incomplete
# 9    Complete
# 10   Complete
# 11   Complete
# 12   Complete
# 13   Incomplete
# 14   Complete
# 15   Complete
# 16   Complete
# 17   Complete
# 18   Complete
# 19   Complete
# 20   Complete
# 21   Complete
# 22   Complete
# 23   Complete
# 24   Complete
# 25   Complete
# 26   Complete
# 27   Complete
# 28   Complete
# 29   Complete
# 30   Complete
# ⋮    ⋮
# 1085 Incomplete
# 1086 Complete
# 1087 Complete
# 1088 Complete
# 1089 Complete
# 1090 Complete
# 1091 Complete
# 1092 Complete
# 1093 Complete
# 1094 Incomplete
# 1095 Complete
# 1096 Complete
# 1097 Complete
# 1098 Complete
# 1099 Complete
# 1100 Incomplete
# 1101 Incomplete
# 1102 Complete
# 1103 Incomplete
# 1104 Complete
# 1105 Incomplete
# 1106 Complete
# 1107 Complete
# 1108 Complete
# 1109 Complete
# 1110 Complete
# 1111 Complete
# 1112 Complete
# 1113 Incomplete
# 1114 Complete

# %% [markdown]
# ## Number of incomplete and complete responses

# %%
# Complete vs incomplete for general data
table(final_data$Q819)
# Out:
#   Complete Incomplete
#        819        295

# %% [markdown]
# # Descriptive Statistics for overall data

# %% [markdown]
# ## Age counts

# %%
# Age
gen_age <- table(final_data$Q162)
gen_age
# Out:
#                 18-24                 25-34                 35-44
#                    31                   204                   256
#                 45-54                 55-64                    65
#                   262                   226                   103
# Prefer not to respond
#                    23

# %% [markdown]
# ## Age percentages

# %%
# Age
gen_age_perc <- prop.table(gen_age)*100
gen_age_perc
# Out:
#                 18-24                 25-34                 35-44
#              2.805430             18.461538             23.167421
#                 45-54                 55-64                    65
#             23.710407             20.452489              9.321267
# Prefer not to respond
#              2.081448

# %% [markdown]
# ## Race counts

# %%
## Race
gen_race <- table(final_data$Q159)
gen_race
# Out:
#         Asian and/or Asian American           Black or African American
#                                  28                                 273
#                         Multiracial    Native American or Alaska Native
#                                  79                                  13
# Native Hawaiian or Pacific Islander               Prefer not to respond
#                                   5                                  55
#             Prefer to self-describe                  White or Caucasian
#                                  26                                 625

# %% [markdown]
# ## Race percentages

# %%
# Race
gen_race_perc <- prop.table(gen_race)*100
gen_race_perc
# Out:
#         Asian and/or Asian American           Black or African American
#                           2.5362319                          24.7282609
#                         Multiracial    Native American or Alaska Native
#                           7.1557971                           1.1775362
# Native Hawaiian or Pacific Islander               Prefer not to respond
#                           0.4528986                           4.9818841
#             Prefer to self-describe                  White or Caucasian
#                           2.3550725                          56.6123188

# %% [markdown]
# ## Hispanic/Latinx counts

# %%
## Hispanic/Latinx
gen_hisp <- table(final_data$Q161)
gen_hisp
# Out:
#                    No Prefer not to respond                   Yes
#                   887                    21                   197

# %% [markdown]
# ## Hispanic/Latinx percentages

# %%
gen_hisp_perc <- prop.table(gen_hisp)*100
gen_hisp_perc
# Out:
#                    No Prefer not to respond                   Yes
#             80.271493              1.900452             17.828054

# %% [markdown]
# ## Type of organization counts

# %%
## Org type
gen_org_type <- table(final_data$Q1)
gen_org_type
# Out:
#              Academic hospital/clinic setting
#                                            80
#                         Advocacy organization
#                                             5
#               AIDS Service Organization (ASO)
#                                           133
#            Community Based Organization (CBO)
#                                           129
#      Federally Qualified Health Center (FQHC)
#                                           134
#     Government entity (Local, State, Federal)
#                                           105
#                Health department (non-clinic)
#                                            41
# Health department clinic/public health clinic
#                                           146
#          LBGTQ Health Center/Community Center
#                                            55
#                       Non-profit organization
#                                           159
#                                         Other
#                                            27
#                                      Pharmacy
#                                             7
#               Private hospital/clinic setting
#                                            36
#                              Private practice
#                                            24
#              Substance use treatment facility
#                                            11
#                            University/college
#                                            22

# %% [markdown]
# ## Type of organization percentages

# %%
gen_org_perc <- prop.table(gen_org_type)*100
gen_org_perc
# Out:
#              Academic hospital/clinic setting
#                                     7.1813285
#                         Advocacy organization
#                                     0.4488330
#               AIDS Service Organization (ASO)
#                                    11.9389587
#            Community Based Organization (CBO)
#                                    11.5798923
#      Federally Qualified Health Center (FQHC)
#                                    12.0287253
#     Government entity (Local, State, Federal)
#                                     9.4254937
#                Health department (non-clinic)
#                                     3.6804309
# Health department clinic/public health clinic
#                                    13.1059246
#          LBGTQ Health Center/Community Center
#                                     4.9371634
#                       Non-profit organization
#                                    14.2728905
#                                         Other
#                                     2.4236984
#                                      Pharmacy
#                                     0.6283662
#               Private hospital/clinic setting
#                                     3.2315978
#                              Private practice
#                                     2.1543986
#              Substance use treatment facility
#                                     0.9874327
#                            University/college
#                                     1.9748654

# %% [markdown]
# ## State counts

# %%
## States
gen_state_counts <- table(final_data$Q3)
gen_state_counts
# Out:
#              Alabama               Alaska              Arizona
#                    8                    1                   15
#             Arkansas           California             Colorado
#                    8                  105                   16
#          Connecticut             Delaware District of Columbia
#                   20                   12                   39
#              Florida              Georgia               Hawaii
#                   64                   26                   11
#                Idaho             Illinois              Indiana
#                    2                   38                   46
#                 Iowa               Kansas             Kentucky
#                   13                    4                   30
#            Louisiana                Maine             Maryland
#                   24                    1                   67
#        Massachusetts             Michigan            Minnesota
#                    7                   43                   16
#          Mississippi             Missouri              Montana
#                    9                   20                    2
#             Nebraska               Nevada        New Hampshire
#                    7                    6                    3
#           New Jersey           New Mexico             New York
#                   55                    4                   76
#       North Carolina                 Ohio             Oklahoma
#                   31                   14                    1
#               Oregon         Pennsylvania          Puerto Rico
#                    9                   69                   10
#         Rhode Island       South Carolina            Tennessee
#                    4                   14                   18
#                Texas                 Utah              Vermont
#                   46                    3                    3
#       Virgin Islands             Virginia           Washington
#                    4                   35                   25
#        West Virginia            Wisconsin              Wyoming
#                    8                   12                    6

# %% [markdown]
# ## State percentages

# %%
gen_state_perc <- prop.table(gen_state_counts)*100
gen_state_perc
# Out:
#              Alabama               Alaska              Arizona
#           0.72072072           0.09009009           1.35135135
#             Arkansas           California             Colorado
#           0.72072072           9.45945946           1.44144144
#          Connecticut             Delaware District of Columbia
#           1.80180180           1.08108108           3.51351351
#              Florida              Georgia               Hawaii
#           5.76576577           2.34234234           0.99099099
#                Idaho             Illinois              Indiana
#           0.18018018           3.42342342           4.14414414
#                 Iowa               Kansas             Kentucky
#           1.17117117           0.36036036           2.70270270
#            Louisiana                Maine             Maryland
#           2.16216216           0.09009009           6.03603604
#        Massachusetts             Michigan            Minnesota
#           0.63063063           3.87387387           1.44144144
#          Mississippi             Missouri              Montana
#           0.81081081           1.80180180           0.18018018
#             Nebraska               Nevada        New Hampshire
#           0.63063063           0.54054054           0.27027027
#           New Jersey           New Mexico             New York
#           4.95495495           0.36036036           6.84684685
#       North Carolina                 Ohio             Oklahoma
#           2.79279279           1.26126126           0.09009009
#               Oregon         Pennsylvania          Puerto Rico
#           0.81081081           6.21621622           0.90090090
#         Rhode Island       South Carolina            Tennessee
#           0.36036036           1.26126126           1.62162162
#                Texas                 Utah              Vermont
#           4.14414414           0.27027027           0.27027027
#       Virgin Islands             Virginia           Washington
#           0.36036036           3.15315315           2.25225225
#        West Virginia            Wisconsin              Wyoming
#           0.72072072           1.08108108           0.54054054

# %% [markdown]
# ## Role counts

# %%
gen_role_counts <- table(final_data$Q66)
gen_role_counts
# Out:
#                              Dentist               Dietician/Nutritionist
#                                    2                                    1
#      Disease Intervention Specialist      Licensed Clinical Social Worker
#                                    1                                   50
#             Licensed Practical Nurse                    Medical Assistant
#                                   10                                   10
#           Mental Health Case Manager              Mental Health Counselor
#                                    5                                    1
#           Mental Health Professional          Mental Health Professional
#                                   15                                    1
#                        Nurse Manager                        Nurse Midwife
#                                   19                                    1
#                   Nurse Practitioner Other Provider/Clinical professional
#                                   69                                    8
#                           Pharmacist                  Pharmacy Technician
#                                   16                                    3
#                         Phlebotomist                   Physical Therapist
#                                    2                                    1
#                            Physician                  Physician Assistant
#                                   57                                   11
#                         Psychologist                     Registered Nurse
#                                   17                                   79

# %% [markdown]
# ## Role percentages

# %%
gen_role_perc <- prop.table(gen_role_counts)*100
gen_role_perc
# Out:
#                              Dentist               Dietician/Nutritionist
#                            0.5277045                            0.2638522
#      Disease Intervention Specialist      Licensed Clinical Social Worker
#                            0.2638522                           13.1926121
#             Licensed Practical Nurse                    Medical Assistant
#                            2.6385224                            2.6385224
#           Mental Health Case Manager              Mental Health Counselor
#                            1.3192612                            0.2638522
#           Mental Health Professional          Mental Health Professional
#                            3.9577836                            0.2638522
#                        Nurse Manager                        Nurse Midwife
#                            5.0131926                            0.2638522
#                   Nurse Practitioner Other Provider/Clinical professional
#                           18.2058047                            2.1108179
#                           Pharmacist                  Pharmacy Technician
#                            4.2216359                            0.7915567
#                         Phlebotomist                   Physical Therapist
#                            0.5277045                            0.2638522
#                            Physician                  Physician Assistant
#                           15.0395778                            2.9023747
#                         Psychologist                     Registered Nurse
#                            4.4854881                           20.8443272

# %% [markdown]
# ## Prescriber counts

# %%
gen_prescriber_counts <- table(final_data$Q70)
gen_prescriber_counts
# Out:
#  No Yes
# 229 154

# %% [markdown]
# ## Prescriber percentage

# %%
gen_prescriber_perc <- prop.table(gen_prescriber_counts)*100
gen_prescriber_perc
# Out:
#       No      Yes
# 59.79112 40.20888

# %% [markdown]
# # HIV training statistics for overall data

# %%
# Create a vector of column names representing the HIV topics columns
hiv_topics <- c("Q198", "Q199", "Q200", "Q201", "Q202","Q203","Q204","Q205","Q206","Q207","Q208","Q209","Q210a","Q210b")

# %% [markdown]
# ## HIV topic with greatest number of 1st rankings

# %%
# Calculate the counts of 1st rankings for each HIV topic
hiv1_counts <- sapply(hiv_topics, function(topic) sum(final_data[[topic]] == 1, na.rm = TRUE))
hiv1_counts
# Out:
#  Q198  Q199  Q200  Q201  Q202  Q203  Q204  Q205  Q206  Q207  Q208  Q209 Q210a
#   181    83    76    18    21    37    34    49    49     6    12    12     3
# Q210b
#     1

# %%
# Find the HIV topic with the highest count of 1st rankings
hiv1 <- hiv_topics[which.max(hiv1_counts)]
hiv1
# Out:
# [1] "Q198"

# %%
# Calculate the percentage of 1st rankings
hiv1_perc <- (hiv1_counts[which.max(hiv1_counts)] / nrow(final_data)) * 100
hiv1_perc
# Out:
#     Q198
# 16.24776

# %% [markdown]
# ## HIV topic with greatest number of 2nd rankings

# %%
# Calculate the counts of 2nd rankings for each HIV topic
hiv2_counts <- sapply(hiv_topics, function(topic) sum(final_data[[topic]] == 2, na.rm = TRUE))
hiv2_counts
# Out:
#  Q198  Q199  Q200  Q201  Q202  Q203  Q204  Q205  Q206  Q207  Q208  Q209 Q210a
#    61    89    76    27    44    52    48    49    56    15    19     2     0
# Q210b
#     1

# %%
# Find the HIV topic with the highest count of 2nd rankings
hiv2 <- hiv_topics[which.max(hiv2_counts)]
hiv2
# Out:
# [1] "Q199"

# %%
# Calculate the percentage of 2nd rankings for the top HIV topic
hiv2_perc <- (hiv2_counts[which.max(hiv2_counts)] / nrow(final_data)) * 100
hiv2_perc
# Out:
#     Q199
# 7.989228

# %% [markdown]
# ## HIV topic with greatest number of 3rd rankings

# %%
# Calculate the counts of 3rd rankings for each HIV topic
hiv3_counts <- sapply(hiv_topics, function(topic) sum(final_data[[topic]] == 3, na.rm = TRUE))
hiv3_counts
# Out:
#  Q198  Q199  Q200  Q201  Q202  Q203  Q204  Q205  Q206  Q207  Q208  Q209 Q210a
#    67    47    56    17    56    46    61    58    53    12    37    16     2
# Q210b
#     3

# %%
# Find the HIV topic with the highest count of 3rd rankings
hiv3 <- hiv_topics[which.max(hiv3_counts)]
hiv3
# Out:
# [1] "Q198"

# %%
# Calculate the percentage of 3rd rankings
hiv3_perc <- (hiv3_counts[which.max(hiv3_counts)] / nrow(final_data)) * 100
hiv3_perc
# Out:
#     Q198
# 6.014363

# %% [markdown]
# ## Top 3 HIV training topics

# %%
# Calculate the counts for each HIV topic
topic_counts <- sapply(hiv_topics, function(topic) sum(topic %in% c(1, 2, 3), na.rm = TRUE))

# Sort the topics based on their counts in descending order
sorted_topics <- sort(topic_counts, decreasing = TRUE)

# Get the top 3 topics
top_3_topics <- names(sorted_topics)[1:3]

top_3_topics
# Out:
# [1] "Q198" "Q199" "Q200"

# %% [markdown]
# # PrEP training statistics for overall data

# %%
# Create a vector of column names representing the PrEP topics columns
prep_topics <- c("Q211", "Q212", "Q213", "Q214", "Q215","Q216","Q217","Q218","Q219","Q220","Q221","Q222","Q223","Q224","Q225")

# %% [markdown]
# ## PrEP topic with greatest number of 1st rankings

# %%
# Calculate the counts of 1st rankings for each PrEP topic
prep1_counts <- sapply(prep_topics, function(topic) sum(final_data[[topic]] == 1, na.rm = TRUE))
prep1_counts
# Out:
# Q211 Q212 Q213 Q214 Q215 Q216 Q217 Q218 Q219 Q220 Q221 Q222 Q223 Q224 Q225
#  124   73   62  108   11   22   20   48   37   31   19   29   36   12    3

# %%
# Find the PrEP topic with the highest count of 1st rankings
prep1 <- prep_topics[which.max(prep1_counts)]
prep1
# Out:
# [1] "Q211"

# %%
# Calculate the percentage of 1st rankings
prep1_perc <- (prep1_counts[which.max(prep1_counts)] / nrow(final_data)) * 100
prep1_perc
# Out:
#     Q211
# 11.13106

# %% [markdown]
# ## PrEP topic with greatest number of 2nd rankings

# %%
# Calculate the counts of 2nd rankings for each PrEP topic
prep2_counts <- sapply(prep_topics, function(topic) sum(final_data[[topic]] == 2, na.rm = TRUE))
prep2_counts
# Out:
# Q211 Q212 Q213 Q214 Q215 Q216 Q217 Q218 Q219 Q220 Q221 Q222 Q223 Q224 Q225
#   29   70   53   80   26   34   37   77   50   39   24   27   41   15    0

# %%
# Find the PrEP topic with the highest count of 2nd rankings
prep2 <- prep_topics[which.max(prep2_counts)]
prep2
# Out:
# [1] "Q214"

# %%
# Calculate the percentage of 2nd rankings for the top PrEP topic
prep2_perc <- (prep2_counts[which.max(prep2_counts)] / nrow(final_data)) * 100
prep2_perc
# Out:
#     Q214
# 7.181329

# %% [markdown]
# ## PrEP topic with greatest number of 3rd rankings

# %%
# Calculate the counts of 3rd rankings for each PrEP topic
prep3_counts <- sapply(prep_topics, function(topic) sum(final_data[[topic]] == 3, na.rm = TRUE))
prep3_counts
# Out:
# Q211 Q212 Q213 Q214 Q215 Q216 Q217 Q218 Q219 Q220 Q221 Q222 Q223 Q224 Q225
#   44   21   43   52   18   35   38   69   26   66   42   46   42   41    5

# %%
# Find the PrEP topic with the highest count of 3rd rankings
prep3 <- prep_topics[which.max(prep3_counts)]
prep3
# Out:
# [1] "Q218"

# %%
# Calculate the percentage of 3rd rankings
prep3_perc <- (prep3_counts[which.max(prep3_counts)] / nrow(final_data)) * 100
prep3_perc
# Out:
#     Q218
# 6.193896

# %% [markdown]
# ## Top 3 PrEP training topics

# %%
# Calculate the counts for each PrEP topic
topic_counts <- sapply(prep_topics, function(topic) sum(topic %in% c(1, 2, 3), na.rm = TRUE))

# Sort the topics based on their counts in descending order
sorted_topics <- sort(topic_counts, decreasing = TRUE)

# Get the top 3 topics
top_3_topics <- names(sorted_topics)[1:3]

top_3_topics
# Out:
# [1] "Q211" "Q212" "Q213"

# %% [markdown]
# # LGBTQ training statistics for overall data

# %%
# Create a vector of column names representing the LGBTQ topics columns
lgbtq_topics <- c("Q227", "Q228", "Q229", "Q230", "Q231","Q232","Q233","Q234","Q235")

# %% [markdown]
# ## LGBTQ topic with greatest number of 1st rankings

# %%
# Calculate the counts of 1st rankings for each LGBTQ topic
lgbtq1_counts <- sapply(lgbtq_topics, function(topic) sum(final_data[[topic]] == 1, na.rm = TRUE))
lgbtq1_counts
# Out:
# Q227 Q228 Q229 Q230 Q231 Q232 Q233 Q234 Q235
#  139  198  121  120   34   67  118  114   15

# %%
# Find the LGBTQ topic with the highest count of 1st rankings
lgbtq1 <- lgbtq_topics[which.max(lgbtq1_counts)]
lgbtq1
# Out:
# [1] "Q228"

# %%
# Calculate the percentage of 1st rankings
lgbtq1_perc <- (lgbtq1_counts[which.max(lgbtq1_counts)] / nrow(final_data)) * 100
lgbtq1_perc
# Out:
#     Q228
# 17.77379

# %% [markdown]
# ## LGBTQ topic with greatest number of 2nd rankings

# %%
# Calculate the counts of 2nd rankings for each LGBTQ topic
lgbtq2_counts <- sapply(lgbtq_topics, function(topic) sum(final_data[[topic]] == 2, na.rm = TRUE))
lgbtq2_counts
# Out:
# Q227 Q228 Q229 Q230 Q231 Q232 Q233 Q234 Q235
#   67  121  102  154   62   78  143  143    4

# %%
# Find the LGBTQ topic with the highest count of 2nd rankings
lgbtq2 <- lgbtq_topics[which.max(lgbtq2_counts)]
lgbtq2
# Out:
# [1] "Q230"

# %%
# Calculate the percentage of 2nd rankings for the top LGBTQ topic
lgbtq2_perc <- (lgbtq2_counts[which.max(lgbtq2_counts)] / nrow(final_data)) * 100
lgbtq2_perc
# Out:
#     Q230
# 13.82406

# %% [markdown]
# ## LGBTQ topic with greatest number of 3rd rankings

# %%
# Calculate the counts of 3rd rankings for each LGBTQ topic
lgbtq3_counts <- sapply(lgbtq_topics, function(topic) sum(final_data[[topic]] == 3, na.rm = TRUE))
lgbtq3_counts
# Out:
# Q227 Q228 Q229 Q230 Q231 Q232 Q233 Q234 Q235
#   81  122   73  124   66   64  109  194   14

# %%
# Find the LGBTQ topic with the highest count of 3rd rankings
lgbtq3 <- lgbtq_topics[which.max(lgbtq3_counts)]
lgbtq3
# Out:
# [1] "Q234"

# %%
# Calculate the percentage of 3rd rankings
lgbtq3_perc <- (lgbtq3_counts[which.max(lgbtq3_counts)] / nrow(final_data)) * 100
lgbtq3_perc
# Out:
#     Q234
# 17.41472

# %% [markdown]
# ## Top 3 LGBTQ training topics

# %%
# Calculate the counts for each LGBTQ topic
topic_counts <- sapply(lgbtq_topics, function(topic) sum(topic %in% c(1, 2, 3), na.rm = TRUE))

# Sort the topics based on their counts in descending order
sorted_topics <- sort(topic_counts, decreasing = TRUE)

# Get the top 3 topics
top_3_topics <- names(sorted_topics)[1:3]

top_3_topics
# Out:
# [1] "Q227" "Q228" "Q229"

# %% [markdown]
# # Identifying HIV providers

# %%
# HIV providers
HIV_providers <- final_data[final_data$Q22 == "Yes" | final_data$Q30 == "Yes" | final_data$Q32 == "Yes", ]
HIV_providers
# Out:
#      email                             Record_ID
# 1    NA                                NA
# 2    19tyler@gmail.com                 422
# 3    3sollenberger@gmail.com           1294
# 4    aabundiz@hyacinth.org             1519
# 5    aadegbulugbe@totalhealthcare.org  222
# 6    aalbior@bach.health               1550
# 7    aalcanta@conemaugh.org            1385
# 8    abby.hinz@eauclairecounty.gov     258
# 9    abilly@iuhealth.org               774
# 10   abmontalvo@sbchc.net              1612
# 11   aboatwright@sfcommunityhealth.org 200
# 12   acampos@familycenters.org         83
# 13   acastel@gwu.edu                   391
# 14   aclarke@riversidehealth.org       1008
# 15   Adam.lake@pennmedicine.upenn.edu  901
# 16   addie.zuniga@dph.ga.gov           54
# 17   adelaidamartin@gmail.com          601
# 18   adickerson@yss.org                754
# 19   Admin@connectdcare.com            123
# 20   Aevans@tulane.edu                 473
# 21   aflores@hyacinth.org              1416
# 22   afort1@iuhealth.org               827
# 23   agalarza@cookcountyhhs.org        47
# 24   agannett@hamiltonhealthcenter.com 1234
# 25   Agirmay@kintegra.org              388
# 26   aglorioso@daphealth.org           248
# 27   agnes.santiago-cotto@va.gov       930
# 28   agonzalez@centrocultural.org      6
# 29   agonzalez@tpqc.org                961
# 30   agraham@aidsdelaware.org          1012
# ⋮    ⋮                                 ⋮
# 1009 wedgeben@yahoo.com                24
# 1010 wgarcia@hyacinth.org              808
# 1011 wgrullon@ACRHealth.org            29
# 1012 whitebreads@thewrightcenter.org   61
# 1013 wilfred@wavesahead.org            1062
# 1014 wjenkins@aidsdelaware.org         196
# 1015 wkomis@chicagofamilyhealth.org    386
# 1016 wlaabadawy320@yahoo.com           1283
# 1017 wmote@lrmcenter.com               464
# 1018 wncap@wncap.org                   226
# 1019 wphillips@centerlb.org            651
# 1020 Wrha238@uky.edu                   660
# 1021 Wynnett.Stewart@ynhh.org          207
# 1022 xivcam@gmail.com                  841
# 1023 yamiller83@gmail.com              428
# 1024 yavonne.dubose@dc.gov             555
# 1025 ybell@aboundingprosperity.org     169
# 1026 yesenia.cornejo@wattshealth.org   336
# 1027 yolanda.scott@dc.gov              1356
# 1028 ypb7352@gmail.com                 1135
# 1029 Ypuerto@med.miami.edu             673
# 1030 yudenia@iajems.org                1585
# 1031 yvonnel@cccswla.org               1491
# 1032 zbird@centeronhalsted.org         837
# 1033 zee.stjames@gmail.com             872
# 1034 zfd2yy@uvahealth.org              240
# 1035 zhennessey@gmail.com              1392
# 1036 zmuneton@browardhealth.org        497
# 1037 zpenny@obfh.org                   600
# 1038 zulinew@bebashi.orgrg             1059
#      Q1                                            Q2
# 1    NA                                            NA
# 2    Non-profit organization                       NA
# 3    Non-profit organization                       NA
# 4    Community Based Organization (CBO)            NA
# 5    Federally Qualified Health Center (FQHC)      NA
# 6    Federally Qualified Health Center (FQHC)      NA
# 7    AIDS Service Organization (ASO)               NA
# 8    Health department clinic/public health clinic NA
# 9    AIDS Service Organization (ASO)               NA
# 10   Federally Qualified Health Center (FQHC)      NA
# 11   Health department (non-clinic)                NA
# 12   AIDS Service Organization (ASO)               NA
# 13   Health department clinic/public health clinic NA
# 14   AIDS Service Organization (ASO)               NA
# 15   Academic hospital/clinic setting              NA
# 16   Health department (non-clinic)                NA
# 17   Non-profit organization                       NA
# 18   Non-profit organization                       NA
# 19   Private practice                              NA
# 20   Academic hospital/clinic setting              NA
# 21   Non-profit organization                       NA
# 22   AIDS Service Organization (ASO)               NA
# 23   Health department clinic/public health clinic NA
# 24   Federally Qualified Health Center (FQHC)      NA
# 25   Federally Qualified Health Center (FQHC)      NA
# 26   Federally Qualified Health Center (FQHC)      NA
# 27   Government entity (Local, State, Federal)     NA
# 28   Community Based Organization (CBO)            NA
# 29   AIDS Service Organization (ASO)               NA
# 30   AIDS Service Organization (ASO)               NA
# ⋮    ⋮                                             ⋮
# 1009 LBGTQ Health Center/Community Center          NA
# 1010 LBGTQ Health Center/Community Center          NA
# 1011 Community Based Organization (CBO)            NA
# 1012 Federally Qualified Health Center (FQHC)      NA
# 1013 LBGTQ Health Center/Community Center          NA
# 1014 AIDS Service Organization (ASO)               NA
# 1015 Federally Qualified Health Center (FQHC)      NA
# 1016 Other                                         king khalid
# 1017 Federally Qualified Health Center (FQHC)      NA
# 1018 AIDS Service Organization (ASO)               NA
# 1019 LBGTQ Health Center/Community Center          NA
# 1020 Other                                         HIV/HepC health education
# 1021 Academic hospital/clinic setting              NA
# 1022 Government entity (Local, State, Federal)     NA
# 1023 Non-profit organization                       NA
# 1024 Government entity (Local, State, Federal)     NA
# 1025 Community Based Organization (CBO)            NA
# 1026 Community Based Organization (CBO)            NA
# 1027 Government entity (Local, State, Federal)     NA
# 1028 LBGTQ Health Center/Community Center          NA
# 1029 Private hospital/clinic setting               NA
# 1030 Non-profit organization                       NA
# 1031 Community Based Organization (CBO)            NA
# 1032 LBGTQ Health Center/Community Center          NA
# 1033 Advocacy organization                         NA
# 1034 Academic hospital/clinic setting              NA
# 1035 Non-profit organization                       NA
# 1036 Non-profit organization                       NA
# 1037 Federally Qualified Health Center (FQHC)      NA
# 1038 AIDS Service Organization (ASO)               NA
#      Q3                   Q4    Q5       Q6  Q7 Q8 ⋯
# 1    NA                   NA    NA       NA  NA NA ⋯
# 2    District of Columbia 20005 Urban    No   1 NA ⋯
# 3    Pennsylvania         15222 Urban    No   1  1 ⋯
# 4    New Jersey           7060  Suburban No  NA NA ⋯
# 5    Maryland             21223 Urban    Yes  1  1 ⋯
# 6    California           94538 Suburban No  NA NA ⋯
# 7    Pennsylvania         15905 Rural    No   1  1 ⋯
# 8    Wisconsin            54703 Urban    Yes  1 NA ⋯
# 9    Indiana              47909 Urban    No   1  1 ⋯
# 10   Texas                77055 Urban    No   1  1 ⋯
# 11   California           94102 Urban    No   1  1 ⋯
# 12   Connecticut          6902  Suburban No  NA NA ⋯
# 13   District of Columbia 20002 Urban    No   1  1 ⋯
# 14   New York             10703 Urban    Yes  1  1 ⋯
# 15   Pennsylvania         17602 Suburban Yes  1  1 ⋯
# 16   Georgia              30008 Suburban Yes  1 NA ⋯
# 17   District of Columbia 20017 Urban    No   1  1 ⋯
# 18   Iowa                 50010 Suburban No   1 NA ⋯
# 19   Delaware             19901 Rural    No   1  1 ⋯
# 20   Louisiana            71301 Suburban Yes  1  1 ⋯
# 21   New Jersey           7306  Urban    No  NA NA ⋯
# 22   Indiana              47401 Suburban No   1  1 ⋯
# 23   Illinois             60612 Urban    Yes  1  1 ⋯
# 24   Pennsylvania         17104 Urban    Yes  1  1 ⋯
# 25   North Carolina       28052 Suburban Yes  1  1 ⋯
# 26   California           92262 Urban    Yes  1  1 ⋯
# 27   Puerto Rico          921   Urban    Yes NA NA ⋯
# 28   Oregon               97113 Suburban No  NA NA ⋯
# 29   Illinois             61265 Rural    Yes NA NA ⋯
# 30   Delaware             19801 Urban    No   1  1 ⋯
# ⋮    ⋮                    ⋮     ⋮        ⋮   ⋮  ⋮  ⋱
# 1009 California           90048 Urban    Yes NA NA ⋯
# 1010 New Jersey           7501  Urban    No  NA NA ⋯
# 1011 New York             13501 Rural    No   1 NA ⋯
# 1012 Pennsylvania         18505 Urban    Yes  1  1 ⋯
# 1013 Puerto Rico          921   Suburban No  NA NA ⋯
# 1014 Delaware             19801 Urban    No   1  1 ⋯
# 1015 Illinois             60617 Urban    No   1  1 ⋯
# 1016 Illinois             61411 Suburban Yes NA NA ⋯
# 1017 South Carolina       29566 Urban    Yes  1  1 ⋯
# 1018 North Carolina       28803 Urban    No  NA NA ⋯
# 1019 California           90814 Urban    No   1  1 ⋯
# 1020 Kentucky             40258 Suburban Yes  1  1 ⋯
# 1021 Connecticut          6510  Urban    Yes  1  1 ⋯
# 1022 Oregon               97232 Urban    No  NA NA ⋯
# 1023 Puerto Rico          612   Urban    No   1  1 ⋯
# 1024 District of Columbia 20003 Urban    No  NA NA ⋯
# 1025 Texas                75215 Urban    Yes  1  1 ⋯
# 1026 California           90002 Urban    No   1  1 ⋯
# 1027 District of Columbia 20002 Urban    No   1  1 ⋯
# 1028 Hawaii               96813 Urban    No   1  1 ⋯
# 1029 Florida              33136 Urban    Yes  1  1 ⋯
# 1030 Mississippi          39202 Rural    No  NA NA ⋯
# 1031 Louisiana            70601 Rural    Yes  1  1 ⋯
# 1032 Illinois             60613 Urban    No   1  1 ⋯
# 1033 Michigan             48202 Urban    No  NA NA ⋯
# 1034 Virginia             22903 Suburban Yes  1  1 ⋯
# 1035 New York             10003 Urban    No   1  1 ⋯
# 1036 Florida              33316 Urban    Yes  1 NA ⋯
# 1037 Florida              32805 Urban    Yes  1  1 ⋯
# 1038 Pennsylvania         19123 Rural    No   1  1 ⋯
#      Q810
# 1    NA
# 2    fear of how far laws will go  and stigmatizingp -
# 3    NA
# 4    NA
# 5    NA
# 6    NA
# 7    NA
# 8    NA
# 9    NA
# 10   NA
# 11   NA
# 12   NA
# 13   NA
# 14   NA
# 15   Worse mental health in trans community
# 16   NA
# 17   NA
# 18   suicide rate is going to increase
# 19   Yes
# 20   NA
# 21   NA
# 22   It deters them from being out and honest to their healthcare providers
# 23   NA
# 24   NA
# 25   NA
# 26   NA
# 27   NA
# 28   NA
# 29   It is hurting, scaring, and will be killing people - in IOWA
# 30   NA
# ⋮    ⋮
# 1009 NA
# 1010 NA
# 1011 NA
# 1012 NA
# 1013 NA
# 1014 NA
# 1015 NA
# 1016 NA
# 1017 NA
# 1018 They are mean spirited laws.
# 1019 NA
# 1020 NA
# 1021 NA
# 1022 NA
# 1023 they feel worried that they may soon not have access to care.
# 1024 NA
# 1025 NA
# 1026 NA
# 1027 NA
# 1028 It will expand services
# 1029 NA
# 1030 NA
# 1031 NA
# 1032 NA
# 1033 NA
# 1034 NA
# 1035 They discourage providers from offering affirming care
# 1036 clients are afraid.
# 1037 NA
# 1038 NA
#      Q811
# 1    NA
# 2    Unsure
# 3    Yes
# 4    Unsure
# 5    Yes
# 6    Yes
# 7    NA
# 8    Yes
# 9    Yes
# 10   Unsure
# 11   NA
# 12   Yes
# 13   Yes
# 14   Unsure
# 15   Yes
# 16   Yes
# 17   Yes
# 18   Yes
# 19   Yes
# 20   Unsure
# 21   Unsure
# 22   Yes
# 23   Unsure
# 24   Yes
# 25   Yes
# 26   Yes
# 27   Unsure
# 28   Unsure
# 29   Yes
# 30   Yes
# ⋮    ⋮
# 1009 Yes
# 1010 NA
# 1011 Yes
# 1012 No
# 1013 Yes
# 1014 Unsure
# 1015 Unsure
# 1016 No
# 1017 Yes
# 1018 Unsure
# 1019 NA
# 1020 No
# 1021 Unsure
# 1022 Yes
# 1023 Yes
# 1024 NA
# 1025 NA
# 1026 Unsure
# 1027 NA
# 1028 Yes
# 1029 NA
# 1030 Unsure
# 1031 No
# 1032 Yes
# 1033 Yes
# 1034 Unsure
# 1035 Yes
# 1036 Yes
# 1037 NA
# 1038 Unsure
#      Q812
# 1    NA
# 2    fear
# 3    NA
# 4    NA
# 5    increases stress due to more stigma and discrimination
# 6    NA
# 7    NA
# 8    Feel less support for the general community/society
# 9    NA
# 10   NA
# 11   NA
# 12   Fear of lack of care
# 13   No one has explicitly said it but I would image it has
# 14   NA
# 15   Not sure where to start
# 16   NA
# 17   Patient are afraid of getting hurt
# 18   NA
# 19   It has
# 20   NA
# 21   NA
# 22   It increases stress and danger, thereby increasing the health risks associated with long-term stress trauma
# 23   NA
# 24   Our trans patients consistently worry about the state of politics and how it impacts their lives and humanity
# 25   It is not right to deny healthcare because of their gender
# 26   NA
# 27   NA
# 28   NA
# 29   It is hurting, scaring, and will be killing people - in IOWA
# 30   NA
# ⋮    ⋮
# 1009 NA
# 1010 NA
# 1011 NA
# 1012 I have not heard anything
# 1013 Increase utilization of support groups and services due to anxiety and depression by patients
# 1014 NA
# 1015 Illinois has some of the most progressive gender affirming care policies, but the national negative anti-trans legislation likely still has an impact.
# 1016 NA
# 1017 Many are afraid to talk about their gender now.
# 1018 Probably has, but don't know specific thoughts of people.
# 1019 NA
# 1020 N/a
# 1021 I know that discrimination of any kind whether direct or indirect negatively impacts mental health of the affected community
# 1022 it's inflicting trauma
# 1023 thay are even scared of traveling and been in a state that could kill them
# 1024 NA
# 1025 NA
# 1026 NA
# 1027 NA
# 1028 It has!
# 1029 NA
# 1030 NA
# 1031 The agency provides gender-affirming care to youth so there are no issues in this area.
# 1032 Even being in a predominant liberal state like IL, the trans community is still facing mental health crisis for the fear that their rights here could go away if the offensive laws from FL move up north.
# 1033 minority stress is only compounded when anti trans messages increase. People are on eddge, worrying about their safety, and may delay or stop gender affirming care.
# 1034 NA
# 1035 Discrimination produces chronic, toxic stress
# 1036 increase stigma
# 1037 NA
# 1038 NA
#      Q813 Q814 Q815 Q816
# 1    NA   NA   NA   NA
# 2    No   NA   Yes  Yes
# 3    No   NA   No   NA
# 4    No   NA   No   NA
# 5    No   NA   No   NA
# 6    No   NA   No   NA
# 7    NA   NA   NA   NA
# 8    No   NA   No   NA
# 9    No   NA   No   NA
# 10   No   NA   No   NA
# 11   NA   NA   NA   NA
# 12   No   NA   No   NA
# 13   No   NA   Yes  Yes
# 14   No   NA   No   NA
# 15   No   NA   Yes  Yes
# 16   No   NA   NA   NA
# 17   No   NA   No   NA
# 18   No   NA   Yes  Yes
# 19   Yes  NA   Yes  Yes
# 20   No   NA   No   NA
# 21   No   NA   NA   NA
# 22   No   NA   Yes  Yes
# 23   No   NA   No   NA
# 24   No   NA   Yes  Yes
# 25   No   NA   No   NA
# 26   No   NA   No   NA
# 27   No   NA   No   NA
# 28   No   NA   NA   NA
# 29   No   NA   No   NA
# 30   No   NA   NA   NA
# ⋮    ⋮    ⋮    ⋮    ⋮
# 1009 Yes  NA   Yes  Yes
# 1010 NA   NA   NA   NA
# 1011 No   NA   No   NA
# 1012 No   NA   No   NA
# 1013 No   NA   No   NA
# 1014 No   NA   NA   NA
# 1015 No   NA   No   NA
# 1016 No   NA   NA   NA
# 1017 No   NA   No   NA
# 1018 No   NA   Yes  Yes
# 1019 NA   NA   NA   NA
# 1020 No   NA   No   NA
# 1021 No   NA   No   NA
# 1022 No   NA   No   NA
# 1023 No   NA   NA   NA
# 1024 NA   NA   NA   NA
# 1025 NA   NA   NA   NA
# 1026 No   NA   No   NA
# 1027 NA   NA   NA   NA
# 1028 No   NA   No   NA
# 1029 NA   NA   NA   NA
# 1030 No   NA   NA   NA
# 1031 No   NA   No   NA
# 1032 No   NA   No   NA
# 1033 No   NA   Yes  Yes
# 1034 No   NA   NA   NA
# 1035 No   NA   NA   NA
# 1036 No   NA   No   NA
# 1037 NA   NA   NA   NA
# 1038 No   NA   No   NA
#      Q817
# 1    NA
# 2    gov refuses to use evidenced based data
# 3    NA
# 4    NA
# 5    NA
# 6    NA
# 7    NA
# 8    NA
# 9    NA
# 10   NA
# 11   NA
# 12   NA
# 13   being able to access SSPs likely reduces their HIV risk
# 14   NA
# 15   I haven't been able to provide colocated services or openly partner with the harm reduction coalition due to my health system's concern over legality
# 16   NA
# 17   NA
# 18   possession of fentynal strip are illegal
# 19   It does
# 20   NA
# 21   NA
# 22   Increase in sharing or reusing IDU materials, raising the risks of HIV/HCV transmission
# 23   NA
# 24   SSP are so important and making them illegal does more harm than good. Morality has no place in healthcare.
# 25   NA
# ...
# 1015 NA
# 1016 NA
# 1017 NA
# 1018 People are at a high level of stress.  Hope suicides don't increase.  Wish we could get rid of guns.
# 1019 NA
# 1020 No
# 1021 NA
# 1022 NA
# 1023 NA
# 1024 NA
# 1025 NA
# 1026 NA
# 1027 NA
# 1028 NA
# 1029 NA
# 1030 NA
# 1031 This work is challenging and tedious but worth it!
# 1032 NA
# 1033 As a program that deals with key populations (sex workers), we have countless barriers to entering this field. Our employees often need more support than we are able to provide. Peer services training does not account for the many intersecting barriers that people who do sex work encounter when trying to achieve employment & learn new skills. There is so much red tape and beuaracracy in the 'legacy' HIV programs that many are not open to grassroots groups such as ourselves. They support criminalization, and spread myths about paraphernalia litter. They want to gatekeep these careers from us.
# 1034 NA
# 1035 NA
# 1036 no
# 1037 NA
# 1038 NA
#      Q819
# 1    NA
# 2    Complete
# 3    Complete
# 4    Complete
# 5    Complete
# 6    Complete
# 7    Incomplete
# 8    Complete
# 9    Complete
# 10   Complete
# 11   Incomplete
# 12   Complete
# 13   Complete
# 14   Complete
# 15   Complete
# 16   Complete
# 17   Complete
# 18   Complete
# 19   Complete
# 20   Complete
# 21   Complete
# 22   Complete
# 23   Complete
# 24   Complete
# 25   Complete
# 26   Complete
# 27   Complete
# 28   Complete
# 29   Complete
# 30   Complete
# ⋮    ⋮
# 1009 Complete
# 1010 Incomplete
# 1011 Complete
# 1012 Complete
# 1013 Complete
# 1014 Complete
# 1015 Complete
# 1016 Complete
# 1017 Complete
# 1018 Complete
# 1019 Incomplete
# 1020 Complete
# 1021 Complete
# 1022 Complete
# 1023 Complete
# 1024 Incomplete
# 1025 Incomplete
# 1026 Complete
# 1027 Incomplete
# 1028 Complete
# 1029 Incomplete
# 1030 Complete
# 1031 Complete
# 1032 Complete
# 1033 Complete
# 1034 Complete
# 1035 Complete
# 1036 Complete
# 1037 Incomplete
# 1038 Complete

# %% [markdown]
# ## Number of incomplete and complete responses among HIV providers

# %%
# Complete vs Incomplete among HIV providers
table(HIV_providers$Q819)
# Out:
#   Complete Incomplete
#        760        271

# %% [markdown]
# ## Descriptive Statistics among HIV providers

# %% [markdown]
# ### Age counts among HIV providers

# %%
## HIV providers - Age
age_HIV <- table(HIV_providers$Q162)
age_HIV
# Out:
#                 18-24                 25-34                 35-44
#                    31                   196                   239
#                 45-54                 55-64                    65
#                   249                   204                    91
# Prefer not to respond
#                    19

# %% [markdown]
# ### Age percentages among HIV providers

# %%
age_perc_HIV <- prop.table(age_HIV)*100
age_perc_HIV
# Out:
#                 18-24                 25-34                 35-44
#              3.012634             19.047619             23.226433
#                 45-54                 55-64                    65
#             24.198251             19.825073              8.843537
# Prefer not to respond
#              1.846453

# %% [markdown]
# ### Gender counts among HIV providers

# %%
## HIV providers - Gender
gender_HIV<- table(HIV_providers$Q157)
gender_HIV
# Out:
#                                 Female/Woman
#                                          636
# Genderqueer/gender non-confirming/non-binary
#                                           64
#                                     Male/Man
#                                          271
#                        Prefer not to respond
#                                           17
#                      Prefer to self-describe
#                                            9
#                              Transgender man
#                                           18
#                            Transgender woman
#                                           14

# %% [markdown]
# ### Gender percentages among HIV providers

# %%
gender_perc_HIV <- prop.table(gender_HIV)*100
gender_perc_HIV
# Out:
#                                 Female/Woman
#                                   61.8075802
# Genderqueer/gender non-confirming/non-binary
#                                    6.2196307
#                                     Male/Man
#                                   26.3362488
#                        Prefer not to respond
#                                    1.6520894
#                      Prefer to self-describe
#                                    0.8746356
#                              Transgender man
#                                    1.7492711
#                            Transgender woman
#                                    1.3605442

# %% [markdown]
# ### Race counts among HIV providers

# %%
## HIV providers - Race
race_HIV <- table(HIV_providers$Q159)
race_HIV
# Out:
#         Asian and/or Asian American           Black or African American
#                                  26                                 250
#                         Multiracial    Native American or Alaska Native
#                                  77                                  11
# Native Hawaiian or Pacific Islander               Prefer not to respond
#                                   5                                  52
#             Prefer to self-describe                  White or Caucasian
#                                  25                                 582

# %% [markdown]
# ### Race percentages among HIV providers

# %%
race_perc_HIV <- prop.table(race_HIV)*100
race_perc_HIV
# Out:
#         Asian and/or Asian American           Black or African American
#                           2.5291829                          24.3190661
#                         Multiracial    Native American or Alaska Native
#                           7.4902724                           1.0700389
# Native Hawaiian or Pacific Islander               Prefer not to respond
#                           0.4863813                           5.0583658
#             Prefer to self-describe                  White or Caucasian
#                           2.4319066                          56.6147860

# %% [markdown]
# ### Hispanic/Latinx counts among HIV providers

# %%
## HIV providers - Hispanic/Latinx
hisp_HIV <- table(HIV_providers$Q161)
hisp_HIV
# Out:
#                    No Prefer not to respond                   Yes
#                   819                    19                   191

# %% [markdown]
# ### Hispanic/Latinx percentages among HIV providers

# %%
hisp_perc_HIV<- prop.table(hisp_HIV)*100
hisp_perc_HIV
# Out:
#                    No Prefer not to respond                   Yes
#             79.591837              1.846453             18.561710

# %% [markdown]
# ### Role counts among HIV providers

# %%
role_counts_HIV <- table(HIV_providers$Q66)
role_counts_HIV
# Out:
#                              Dentist      Disease Intervention Specialist
#                                    2                                    1
#      Licensed Clinical Social Worker             Licensed Practical Nurse
#                                   37                                   10
#                    Medical Assistant           Mental Health Case Manager
#                                   10                                    3
#              Mental Health Counselor           Mental Health Professional
#                                    1                                   11
#          Mental Health Professional                         Nurse Manager
#                                    1                                   18
#                        Nurse Midwife                   Nurse Practitioner
#                                    1                                   68
# Other Provider/Clinical professional                           Pharmacist
#                                    7                                   16
#                  Pharmacy Technician                         Phlebotomist
#                                    3                                    2
#                            Physician                  Physician Assistant
#                                   54                                   11
#                         Psychologist                     Registered Nurse
#                                   14                                   73

# %% [markdown]
# ### Role percentages among HIV providers

# %%
role_perc_HIV <- prop.table(role_counts_HIV)*100
role_perc_HIV
# Out:
#                              Dentist      Disease Intervention Specialist
#                            0.5830904                            0.2915452
#      Licensed Clinical Social Worker             Licensed Practical Nurse
#                           10.7871720                            2.9154519
#                    Medical Assistant           Mental Health Case Manager
#                            2.9154519                            0.8746356
#              Mental Health Counselor           Mental Health Professional
#                            0.2915452                            3.2069971
#          Mental Health Professional                         Nurse Manager
#                            0.2915452                            5.2478134
#                        Nurse Midwife                   Nurse Practitioner
#                            0.2915452                           19.8250729
# Other Provider/Clinical professional                           Pharmacist
#                            2.0408163                            4.6647230
#                  Pharmacy Technician                         Phlebotomist
#                            0.8746356                            0.5830904
#                            Physician                  Physician Assistant
#                           15.7434402                            3.2069971
#                         Psychologist                     Registered Nurse
#                            4.0816327                           21.2827988

# %% [markdown]
# ### Prescriber counts among HIV providers

# %%
prescriber_counts_HIV <- table(HIV_providers$Q70)
prescriber_counts_HIV
# Out:
#  No Yes
# 198 149

# %% [markdown]
# ### Prescriber percentages among HIV providers

# %%
prescriber_perc_HIV <- prop.table(prescriber_counts_HIV)*100
prescriber_perc_HIV
# Out:
#       No      Yes
# 57.06052 42.93948

# %% [markdown]
# ## HIV training statistics for HIV providers

# %%
# HIV providers - Create a vector of column names representing the HIV topics columns
hiv_topics_HIV <- c("Q198", "Q199", "Q200", "Q201", "Q202","Q203","Q204","Q205","Q206","Q207","Q208","Q209","Q210a","Q210b")

# %% [markdown]
# ### HIV topic with greatest number of 1st rankings among HIV providers

# %%
# HIV providers - Calculate the counts of 1st rankings for each HIV topic
hiv1_count_HIV <- sapply(hiv_topics_HIV, function(topic) sum(HIV_providers[[topic]] == 1, na.rm = TRUE))
hiv1_count_HIV
# Out:
#  Q198  Q199  Q200  Q201  Q202  Q203  Q204  Q205  Q206  Q207  Q208  Q209 Q210a
#   181    83    76    18    21    37    34    49    49     6    12    12     3
# Q210b
#     1

# %%
# HIV providers - Find the HIV topic with the highest count of 1st rankings
hiv1_rank_HIV <- hiv_topics_HIV[which.max(hiv1_count_HIV)]
hiv1_rank_HIV
# Out:
# [1] "Q198"

# %%
# HIV providers - Calculate the percentage of 1st rankings
hiv1_perc_HIV <- (hiv1_count_HIV[which.max(hiv1_count_HIV)] / sum(rowSums(!is.na(HIV_providers[, hiv_topics_HIV])) > 0)) * 100
hiv1_perc_HIV
# Out:
#     Q198
# 30.83475

# %% [markdown]
# ### HIV topic with greatest number of 2nd rankings among HIV providers

# %%
# HIV providers - Calculate the counts of 2nd rankings for each HIV topic
hiv2_count_HIV <- sapply(hiv_topics_HIV, function(topic) sum(HIV_providers[[topic]] == 2, na.rm = TRUE))
hiv2_count_HIV
# Out:
#  Q198  Q199  Q200  Q201  Q202  Q203  Q204  Q205  Q206  Q207  Q208  Q209 Q210a
#    61    89    76    27    44    52    48    49    56    15    19     2     0
# Q210b
#     1

# %%
# HIV providers - Find the HIV topic with the highest count of 2nd rankings
hiv2_rank_HIV <- hiv_topics_HIV[which.max(hiv2_count_HIV)]
hiv2_rank_HIV
# Out:
# [1] "Q199"

# %%
# HIV providers - Calculate the percentage of 2nd ranking
hiv2_perc_HIV <- (hiv2_count_HIV[which.max(hiv2_count_HIV)] / sum(rowSums(!is.na(HIV_providers[, hiv_topics_HIV])) > 0)) * 100
hiv2_perc_HIV
# Out:
#     Q199
# 15.16184

# %% [markdown]
# ### HIV topic with greatest number of 3rd rankings among HIV providers

# %%
# HIV providers - Calculate the counts of 3rd rankings for each HIV topic
hiv3_count_HIV <- sapply(hiv_topics_HIV, function(topic) sum(HIV_providers[[topic]] == 3, na.rm = TRUE))
hiv3_count_HIV
# Out:
#  Q198  Q199  Q200  Q201  Q202  Q203  Q204  Q205  Q206  Q207  Q208  Q209 Q210a
#    67    47    56    17    56    46    61    58    53    12    37    16     2
# Q210b
#     3

# %%
# HIV providers - Find the HIV topic with the highest count of 3rd rankings
hiv3_rank_HIV <- hiv_topics_HIV[which.max(hiv3_count_HIV)]
hiv3_rank_HIV
# Out:
# [1] "Q198"

# %%
# HIV providers - Calculate the percentage of 3rd rankings
hiv3_perc_HIV <- (hiv3_count_HIV[which.max(hiv3_count_HIV)] / sum(rowSums(!is.na(HIV_providers[, hiv_topics_HIV])) > 0)) * 100
hiv3_perc_HIV
# Out:
#     Q198
# 11.41397

# %% [markdown]
# ### Top 3 HIV topics among HIV providers

# %%
# Calculate the counts for each PrEP topic
topic_counts_HIV <- sapply(hiv_topics_HIV, function(topic) sum(HIV_providers[[topic]] %in% c(1, 2, 3), na.rm = TRUE))
topic_counts_HIV

# Sort the topics based on their counts in descending order
sorted_topics_HIV <- sort(topic_counts_HIV, decreasing = TRUE)

# Get the top 3 topics
top_3_topics_HIV <- names(sorted_topics_HIV)[1:3]

top_3_topics_HIV
# Out:
#  Q198  Q199  Q200  Q201  Q202  Q203  Q204  Q205  Q206  Q207  Q208  Q209 Q210a
#   309   219   208    62   121   135   143   156   158    33    68    30     5
# Q210b
#     5
# [1] "Q198" "Q199" "Q200"

# %% [markdown]
# ## Prep training statistics for HIV providers

# %%
# HIV providers - Create a vector of column names representing the PrEP topics columns
prep_topics_HIV <- c("Q211", "Q212", "Q213", "Q214", "Q215","Q216","Q217","Q218","Q219","Q220","Q221","Q222","Q223","Q224","Q225")

# %% [markdown]
# ### PrEP topic with greatest number of 1st rankings among HIV providers

# %%
# HIV providers - Calculate the counts of 1st rankings for each PrEP topic
prep1_count_HIV <- sapply(prep_topics_HIV, function(topic) sum(HIV_providers[[topic]] == 1, na.rm = TRUE))
prep1_count_HIV
# Out:
# Q211 Q212 Q213 Q214 Q215 Q216 Q217 Q218 Q219 Q220 Q221 Q222 Q223 Q224 Q225
#  124   73   62  108   11   22   20   48   37   31   19   29   36   12    3

# %%
# HIV providers - Find the PrEP topic with the highest count of 1st rankings
prep1_rank_HIV <- prep_topics_HIV[which.max(prep1_count_HIV)]
prep1_rank_HIV
# Out:
# [1] "Q211"

# %%
# HIV providers - Calculate the percentage of 1st rankings
prep1_perc_HIV <- (prep1_count_HIV[which.max(prep1_count_HIV)] / sum(rowSums(!is.na(HIV_providers[, prep_topics_HIV])) > 0)) * 100
prep1_perc_HIV
# Out:
#    Q211
# 19.2846

# %% [markdown]
# ### PrEP topic with greatest number of 2nd rankings among HIV providers

# %%
# HIV providers - Calculate the counts of 2nd rankings for each PrEP topic
prep2_count_HIV <- sapply(prep_topics_HIV, function(topic) sum(HIV_providers[[topic]] == 2, na.rm = TRUE))
prep2_count_HIV
# Out:
# Q211 Q212 Q213 Q214 Q215 Q216 Q217 Q218 Q219 Q220 Q221 Q222 Q223 Q224 Q225
#   29   70   53   80   26   34   37   77   50   39   24   27   41   15    0

# %%
# HIV providers - Find the PrEP topic with the highest count of 2nd rankings
prep2_rank_HIV <- prep_topics_HIV[which.max(prep2_count_HIV)]
prep2_rank_HIV
# Out:
# [1] "Q214"

# %%
# HIV providers - Calculate the percentage of 2nd ranking
prep2_perc_HIV <- (prep2_count_HIV[which.max(prep2_count_HIV)] / sum(rowSums(!is.na(HIV_providers[, prep_topics_HIV])) > 0)) * 100
prep2_perc_HIV
# Out:
#     Q214
# 12.44168

# %% [markdown]
# ### PrEP topic with greatest number of 3rd rankings among HIV providers

# %%
# HIV providers - Calculate the counts of 3rd rankings for each PrEP topic
prep3_count_HIV <- sapply(prep_topics_HIV, function(topic) sum(HIV_providers[[topic]] == 3, na.rm = TRUE))
prep3_count_HIV
# Out:
# Q211 Q212 Q213 Q214 Q215 Q216 Q217 Q218 Q219 Q220 Q221 Q222 Q223 Q224 Q225
#   44   21   43   52   18   35   38   69   26   66   42   46   42   41    5

# %%
# HIV providers - Find the PrEP topic with the highest count of 3rd rankings
prep3_rank_HIV <- prep_topics_HIV[which.max(prep3_count_HIV)]
prep3_rank_HIV
# Out:
# [1] "Q218"

# %%
# HIV providers - Calculate the percentage of 3rd rankings
prep3_perc_HIV <- (prep3_count_HIV[which.max(prep3_count_HIV)] / sum(rowSums(!is.na(HIV_providers[, prep_topics_HIV])) > 0)) * 100
prep3_perc_HIV
# Out:
#     Q218
# 10.73095

# %% [markdown]
# ### Top 3 PrEP topics among HIV providers

# %%
# Calculate the counts for each PrEP topic
topic_counts_HIV <- sapply(prep_topics_HIV, function(topic) sum(HIV_providers[[topic]] %in% c(1, 2, 3), na.rm = TRUE))
topic_counts_HIV

# Sort the topics based on their counts in descending order
sorted_topics_HIV <- sort(topic_counts_HIV, decreasing = TRUE)

# Get the top 3 topics
top_3_topics_HIV <- names(sorted_topics_HIV)[1:3]

top_3_topics_HIV
# Out:
# Q211 Q212 Q213 Q214 Q215 Q216 Q217 Q218 Q219 Q220 Q221 Q222 Q223 Q224 Q225
#  197  164  158  240   55   91   95  194  113  136   85  102  119   68    8
# [1] "Q214" "Q211" "Q218"

# %% [markdown]
# ## Identifying LGBTQ providers

# %%
# LGBTQ providers
LGBTQ_providers <- final_data[final_data$Q275 == "Yes" | final_data$Q130 == 1 | final_data$Q1 == "LBGTQ Health Center/Community Center" | final_data$Q22 == "Yes" | final_data$Q33 == 1, ]
LGBTQ_providers
# Out:
#      email                             Record_ID
# 1                                      1136
# 2    19tyler@gmail.com                 422
# 3    3sollenberger@gmail.com           1294
# 4    NA                                NA
# 5    aabundiz@hyacinth.org             1519
# 6    aadegbulugbe@totalhealthcare.org  222
# 7    aalbior@bach.health               1550
# 8    aalcanta@conemaugh.org            1385
# 9    abby.hinz@eauclairecounty.gov     258
# 10   NA                                NA
# 11   abilly@iuhealth.org               774
# 12   abmontalvo@sbchc.net              1612
# 13   aboatwright@sfcommunityhealth.org 200
# 14   acampos@familycenters.org         83
# 15   acastel@gwu.edu                   391
# 16   aclarke@riversidehealth.org       1008
# 17   Adam.lake@pennmedicine.upenn.edu  901
# 18   addie.zuniga@dph.ga.gov           54
# 19   adelaidamartin@gmail.com          601
# 20   adickerson@yss.org                754
# 21   Admin@connectdcare.com            123
# 22   Aevans@tulane.edu                 473
# 23   aflores@hyacinth.org              1416
# 24   afort1@iuhealth.org               827
# 25   agalarza@cookcountyhhs.org        47
# 26   agannett@hamiltonhealthcenter.com 1234
# 27   Agirmay@kintegra.org              388
# 28   aglorioso@daphealth.org           248
# 29   agnes.santiago-cotto@va.gov       930
# 30   agonzalez@centrocultural.org      6
# ⋮    ⋮                                 ⋮
# 1085 wgarcia@hyacinth.org              808
# 1086 wgrullon@ACRHealth.org            29
# 1087 whitebreads@thewrightcenter.org   61
# 1088 wilfred@wavesahead.org            1062
# 1089 wjenkins@aidsdelaware.org         196
# 1090 wkomis@chicagofamilyhealth.org    386
# 1091 wlaabadawy320@yahoo.com           1283
# 1092 wmote@lrmcenter.com               464
# 1093 wncap@wncap.org                   226
# 1094 wphillips@centerlb.org            651
# 1095 Wrha238@uky.edu                   660
# 1096 wtyx01@gmail.com                  1266
# 1097 Wynnett.Stewart@ynhh.org          207
# 1098 xivcam@gmail.com                  841
# 1099 yamiller83@gmail.com              428
# 1100 yavonne.dubose@dc.gov             555
# 1101 ybell@aboundingprosperity.org     169
# 1102 yesenia.cornejo@wattshealth.org   336
# 1103 yolanda.scott@dc.gov              1356
# 1104 ypb7352@gmail.com                 1135
# 1105 Ypuerto@med.miami.edu             673
# 1106 yudenia@iajems.org                1585
# 1107 yvonnel@cccswla.org               1491
# 1108 zbird@centeronhalsted.org         837
# 1109 zee.stjames@gmail.com             872
# 1110 zfd2yy@uvahealth.org              240
# 1111 zhennessey@gmail.com              1392
# 1112 NA                                NA
# 1113 zpenny@obfh.org                   600
# 1114 zulinew@bebashi.orgrg             1059
#      Q1                                            Q2
# 1    LBGTQ Health Center/Community Center          NA
# 2    Non-profit organization                       NA
# 3    Non-profit organization                       NA
# 4    NA                                            NA
# 5    Community Based Organization (CBO)            NA
# 6    Federally Qualified Health Center (FQHC)      NA
# 7    Federally Qualified Health Center (FQHC)      NA
# 8    AIDS Service Organization (ASO)               NA
# 9    Health department clinic/public health clinic NA
# 10   NA                                            NA
# 11   AIDS Service Organization (ASO)               NA
# 12   Federally Qualified Health Center (FQHC)      NA
# 13   Health department (non-clinic)                NA
# 14   AIDS Service Organization (ASO)               NA
# 15   Health department clinic/public health clinic NA
# 16   AIDS Service Organization (ASO)               NA
# 17   Academic hospital/clinic setting              NA
# 18   Health department (non-clinic)                NA
# 19   Non-profit organization                       NA
# 20   Non-profit organization                       NA
# 21   Private practice                              NA
# 22   Academic hospital/clinic setting              NA
# 23   Non-profit organization                       NA
# 24   AIDS Service Organization (ASO)               NA
# 25   Health department clinic/public health clinic NA
# 26   Federally Qualified Health Center (FQHC)      NA
# 27   Federally Qualified Health Center (FQHC)      NA
# 28   Federally Qualified Health Center (FQHC)      NA
# 29   Government entity (Local, State, Federal)     NA
# 30   Community Based Organization (CBO)            NA
# ⋮    ⋮                                             ⋮
# 1085 LBGTQ Health Center/Community Center          NA
# 1086 Community Based Organization (CBO)            NA
# 1087 Federally Qualified Health Center (FQHC)      NA
# 1088 LBGTQ Health Center/Community Center          NA
# 1089 AIDS Service Organization (ASO)               NA
# 1090 Federally Qualified Health Center (FQHC)      NA
# 1091 Other                                         king khalid
# 1092 Federally Qualified Health Center (FQHC)      NA
# 1093 AIDS Service Organization (ASO)               NA
# 1094 LBGTQ Health Center/Community Center          NA
# 1095 Other                                         HIV/HepC health education
# 1096 Community Based Organization (CBO)            NA
# 1097 Academic hospital/clinic setting              NA
# 1098 Government entity (Local, State, Federal)     NA
# 1099 Non-profit organization                       NA
# 1100 Government entity (Local, State, Federal)     NA
# 1101 Community Based Organization (CBO)            NA
# 1102 Community Based Organization (CBO)            NA
# 1103 Government entity (Local, State, Federal)     NA
# 1104 LBGTQ Health Center/Community Center          NA
# 1105 Private hospital/clinic setting               NA
# 1106 Non-profit organization                       NA
# 1107 Community Based Organization (CBO)            NA
# 1108 LBGTQ Health Center/Community Center          NA
# 1109 Advocacy organization                         NA
# 1110 Academic hospital/clinic setting              NA
# 1111 Non-profit organization                       NA
# 1112 NA                                            NA
# 1113 Federally Qualified Health Center (FQHC)      NA
# 1114 AIDS Service Organization (ASO)               NA
#      Q3                   Q4    Q5       Q6  Q7 Q8 ⋯
# 1    Connecticut          6511  Urban    Yes  1  1 ⋯
# 2    District of Columbia 20005 Urban    No   1 NA ⋯
# 3    Pennsylvania         15222 Urban    No   1  1 ⋯
# 4    NA                   NA    NA       NA  NA NA ⋯
# 5    New Jersey           7060  Suburban No  NA NA ⋯
# 6    Maryland             21223 Urban    Yes  1  1 ⋯
# 7    California           94538 Suburban No  NA NA ⋯
# 8    Pennsylvania         15905 Rural    No   1  1 ⋯
# 9    Wisconsin            54703 Urban    Yes  1 NA ⋯
# 10   NA                   NA    NA       NA  NA NA ⋯
# 11   Indiana              47909 Urban    No   1  1 ⋯
# 12   Texas                77055 Urban    No   1  1 ⋯
# 13   California           94102 Urban    No   1  1 ⋯
# 14   Connecticut          6902  Suburban No  NA NA ⋯
# 15   District of Columbia 20002 Urban    No   1  1 ⋯
# 16   New York             10703 Urban    Yes  1  1 ⋯
# 17   Pennsylvania         17602 Suburban Yes  1  1 ⋯
# 18   Georgia              30008 Suburban Yes  1 NA ⋯
# 19   District of Columbia 20017 Urban    No   1  1 ⋯
# 20   Iowa                 50010 Suburban No   1 NA ⋯
# 21   Delaware             19901 Rural    No   1  1 ⋯
# 22   Louisiana            71301 Suburban Yes  1  1 ⋯
# 23   New Jersey           7306  Urban    No  NA NA ⋯
# 24   Indiana              47401 Suburban No   1  1 ⋯
# 25   Illinois             60612 Urban    Yes  1  1 ⋯
# 26   Pennsylvania         17104 Urban    Yes  1  1 ⋯
# 27   North Carolina       28052 Suburban Yes  1  1 ⋯
# 28   California           92262 Urban    Yes  1  1 ⋯
# 29   Puerto Rico          921   Urban    Yes NA NA ⋯
# 30   Oregon               97113 Suburban No  NA NA ⋯
# ⋮    ⋮                    ⋮     ⋮        ⋮   ⋮  ⋮  ⋱
# 1085 New Jersey           7501  Urban    No  NA NA ⋯
# 1086 New York             13501 Rural    No   1 NA ⋯
# 1087 Pennsylvania         18505 Urban    Yes  1  1 ⋯
# 1088 Puerto Rico          921   Suburban No  NA NA ⋯
# 1089 Delaware             19801 Urban    No   1  1 ⋯
# 1090 Illinois             60617 Urban    No   1  1 ⋯
# 1091 Illinois             61411 Suburban Yes NA NA ⋯
# 1092 South Carolina       29566 Urban    Yes  1  1 ⋯
# 1093 North Carolina       28803 Urban    No  NA NA ⋯
# 1094 California           90814 Urban    No   1  1 ⋯
# 1095 Kentucky             40258 Suburban Yes  1  1 ⋯
# 1096 California           90012 Rural    Yes NA  1 ⋯
# 1097 Connecticut          6510  Urban    Yes  1  1 ⋯
# 1098 Oregon               97232 Urban    No  NA NA ⋯
# 1099 Puerto Rico          612   Urban    No   1  1 ⋯
# 1100 District of Columbia 20003 Urban    No  NA NA ⋯
# 1101 Texas                75215 Urban    Yes  1  1 ⋯
# 1102 California           90002 Urban    No   1  1 ⋯
# 1103 District of Columbia 20002 Urban    No   1  1 ⋯
# 1104 Hawaii               96813 Urban    No   1  1 ⋯
# 1105 Florida              33136 Urban    Yes  1  1 ⋯
# 1106 Mississippi          39202 Rural    No  NA NA ⋯
# 1107 Louisiana            70601 Rural    Yes  1  1 ⋯
# 1108 Illinois             60613 Urban    No   1  1 ⋯
# 1109 Michigan             48202 Urban    No  NA NA ⋯
# 1110 Virginia             22903 Suburban Yes  1  1 ⋯
# 1111 New York             10003 Urban    No   1  1 ⋯
# 1112 NA                   NA    NA       NA  NA NA ⋯
# 1113 Florida              32805 Urban    Yes  1  1 ⋯
# 1114 Pennsylvania         19123 Rural    No   1  1 ⋯
#      Q810
# 1    NA
# 2    fear of how far laws will go  and stigmatizingp -
# 3    NA
# 4    NA
# 5    NA
# 6    NA
# 7    NA
# 8    NA
# 9    NA
# 10   NA
# 11   NA
# 12   NA
# 13   NA
# 14   NA
# 15   NA
# 16   NA
# 17   Worse mental health in trans community
# 18   NA
# 19   NA
# 20   suicide rate is going to increase
# 21   Yes
# 22   NA
# 23   NA
# 24   It deters them from being out and honest to their healthcare providers
# 25   NA
# 26   NA
# 27   NA
# 28   NA
# 29   NA
# 30   NA
# ⋮    ⋮
# 1085 NA
# 1086 NA
# 1087 NA
# 1088 NA
# 1089 NA
# 1090 NA
# 1091 NA
# 1092 NA
# 1093 They are mean spirited laws.
# 1094 NA
# 1095 NA
# 1096 NA
# 1097 NA
# 1098 NA
# 1099 they feel worried that they may soon not have access to care.
# 1100 NA
# 1101 NA
# 1102 NA
# 1103 NA
# 1104 It will expand services
# 1105 NA
# 1106 NA
# 1107 NA
# 1108 NA
# 1109 NA
# 1110 NA
# 1111 They discourage providers from offering affirming care
# 1112 NA
# 1113 NA
# 1114 NA
#      Q811
# 1    NA
# 2    Unsure
# 3    Yes
# 4    NA
# 5    Unsure
# 6    Yes
# 7    Yes
# 8    NA
# 9    Yes
# 10   NA
# 11   Yes
# 12   Unsure
# 13   NA
# 14   Yes
# 15   Yes
# 16   Unsure
# 17   Yes
# 18   Yes
# 19   Yes
# 20   Yes
# 21   Yes
# 22   Unsure
# 23   Unsure
# 24   Yes
# 25   Unsure
# 26   Yes
# 27   Yes
# 28   Yes
# 29   Unsure
# 30   Unsure
# ⋮    ⋮
# 1085 NA
# 1086 Yes
# 1087 No
# 1088 Yes
# 1089 Unsure
# 1090 Unsure
# 1091 No
# 1092 Yes
# 1093 Unsure
# 1094 NA
# 1095 No
# 1096 Yes
# 1097 Unsure
# 1098 Yes
# 1099 Yes
# 1100 NA
# 1101 NA
# 1102 Unsure
# 1103 NA
# 1104 Yes
# 1105 NA
# 1106 Unsure
# 1107 No
# 1108 Yes
# 1109 Yes
# 1110 Unsure
# 1111 Yes
# 1112 NA
# 1113 NA
# 1114 Unsure
#      Q812
# 1    NA
# 2    fear
# 3    NA
# 4    NA
# 5    NA
# 6    increases stress due to more stigma and discrimination
# 7    NA
# 8    NA
# 9    Feel less support for the general community/society
# 10   NA
# 11   NA
# 12   NA
# 13   NA
# 14   Fear of lack of care
# 15   No one has explicitly said it but I would image it has
# 16   NA
# 17   Not sure where to start
# 18   NA
# 19   Patient are afraid of getting hurt
# 20   NA
# 21   It has
# 22   NA
# 23   NA
# 24   It increases stress and danger, thereby increasing the health risks associated with long-term stress trauma
# 25   NA
# 26   Our trans patients consistently worry about the state of politics and how it impacts their lives and humanity
# 27   It is not right to deny healthcare because of their gender
# 28   NA
# 29   NA
# 30   NA
# ⋮    ⋮
# 1085 NA
# 1086 NA
# 1087 I have not heard anything
# 1088 Increase utilization of support groups and services due to anxiety and depression by patients
# 1089 NA
# 1090 Illinois has some of the most progressive gender affirming care policies, but the national negative anti-trans legislation likely still has an impact.
# 1091 NA
# 1092 Many are afraid to talk about their gender now.
# 1093 Probably has, but don't know specific thoughts of people.
# 1094 NA
# 1095 N/a
# 1096 NA
# 1097 I know that discrimination of any kind whether direct or indirect negatively impacts mental health of the affected community
# 1098 it's inflicting trauma
# 1099 thay are even scared of traveling and been in a state that could kill them
# 1100 NA
# 1101 NA
# 1102 NA
# 1103 NA
# 1104 It has!
# 1105 NA
# 1106 NA
# 1107 The agency provides gender-affirming care to youth so there are no issues in this area.
# 1108 Even being in a predominant liberal state like IL, the trans community is still facing mental health crisis for the fear that their rights here could go away if the offensive laws from FL move up north.
# 1109 minority stress is only compounded when anti trans messages increase. People are on eddge, worrying about their safety, and may delay or stop gender affirming care.
# 1110 NA
# 1111 Discrimination produces chronic, toxic stress
# 1112 NA
# 1113 NA
# 1114 NA
#      Q813 Q814 Q815 Q816
# 1    NA   NA   NA   NA
# 2    No   NA   Yes  Yes
# 3    No   NA   No   NA
# 4    NA   NA   NA   NA
# 5    No   NA   No   NA
# 6    No   NA   No   NA
# 7    No   NA   No   NA
# 8    NA   NA   NA   NA
# 9    No   NA   No   NA
# 10   NA   NA   NA   NA
# 11   No   NA   No   NA
# 12   No   NA   No   NA
# 13   NA   NA   NA   NA
# 14   No   NA   No   NA
# 15   No   NA   Yes  Yes
# 16   No   NA   No   NA
# 17   No   NA   Yes  Yes
# 18   No   NA   NA   NA
# 19   No   NA   No   NA
# 20   No   NA   Yes  Yes
# 21   Yes  NA   Yes  Yes
# 22   No   NA   No   NA
# 23   No   NA   NA   NA
# 24   No   NA   Yes  Yes
# 25   No   NA   No   NA
# 26   No   NA   Yes  Yes
# 27   No   NA   No   NA
# 28   No   NA   No   NA
# 29   No   NA   No   NA
# 30   No   NA   NA   NA
# ⋮    ⋮    ⋮    ⋮    ⋮
# 1085 NA   NA   NA   NA
# 1086 No   NA   No   NA
# 1087 No   NA   No   NA
# 1088 No   NA   No   NA
# 1089 No   NA   NA   NA
# 1090 No   NA   No   NA
# 1091 No   NA   NA   NA
# 1092 No   NA   No   NA
# 1093 No   NA   Yes  Yes
# 1094 NA   NA   NA   NA
# 1095 No   NA   No   NA
# 1096 No   NA   NA   NA
# 1097 No   NA   No   NA
# 1098 No   NA   No   NA
# 1099 No   NA   NA   NA
# 1100 NA   NA   NA   NA
# 1101 NA   NA   NA   NA
# 1102 No   NA   No   NA
# 1103 NA   NA   NA   NA
# 1104 No   NA   No   NA
# 1105 NA   NA   NA   NA
# 1106 No   NA   NA   NA
# 1107 No   NA   No   NA
# 1108 No   NA   No   NA
# 1109 No   NA   Yes  Yes
# 1110 No   NA   NA   NA
# 1111 No   NA   NA   NA
# 1112 NA   NA   NA   NA
# 1113 NA   NA   NA   NA
# 1114 No   NA   No   NA
#      Q817
# 1    NA
# 2    gov refuses to use evidenced based data
# 3    NA
# 4    NA
# 5    NA
# 6    NA
# 7    NA
# 8    NA
# 9    NA
# 10   NA
# 11   NA
# 12   NA
# 13   NA
# 14   NA
# 15   being able to access SSPs likely reduces their HIV risk
# 16   NA
# 17   I haven't been able to provide colocated services or openly partner with the harm reduction coalition due to my health system's concern over legality
# 18   NA
# 19   NA
# 20   possession of fentynal strip are illegal
# 21   It does
# 22   NA
# 23   NA
# 24   Increase in sharing or reusing IDU materials, raising the risks of HIV/HCV transmission
# 25   NA
# ...
# 1091 NA
# 1092 NA
# 1093 People are at a high level of stress.  Hope suicides don't increase.  Wish we could get rid of guns.
# 1094 NA
# 1095 No
# 1096 NA
# 1097 NA
# 1098 NA
# 1099 NA
# 1100 NA
# 1101 NA
# 1102 NA
# 1103 NA
# 1104 NA
# 1105 NA
# 1106 NA
# 1107 This work is challenging and tedious but worth it!
# 1108 NA
# 1109 As a program that deals with key populations (sex workers), we have countless barriers to entering this field. Our employees often need more support than we are able to provide. Peer services training does not account for the many intersecting barriers that people who do sex work encounter when trying to achieve employment & learn new skills. There is so much red tape and beuaracracy in the 'legacy' HIV programs that many are not open to grassroots groups such as ourselves. They support criminalization, and spread myths about paraphernalia litter. They want to gatekeep these careers from us.
# 1110 NA
# 1111 NA
# 1112 NA
# 1113 NA
# 1114 NA
#      Q819
# 1    Incomplete
# 2    Complete
# 3    Complete
# 4    NA
# 5    Complete
# 6    Complete
# 7    Complete
# 8    Incomplete
# 9    Complete
# 10   NA
# 11   Complete
# 12   Complete
# 13   Incomplete
# 14   Complete
# 15   Complete
# 16   Complete
# 17   Complete
# 18   Complete
# 19   Complete
# 20   Complete
# 21   Complete
# 22   Complete
# 23   Complete
# 24   Complete
# 25   Complete
# 26   Complete
# 27   Complete
# 28   Complete
# 29   Complete
# 30   Complete
# ⋮    ⋮
# 1085 Incomplete
# 1086 Complete
# 1087 Complete
# 1088 Complete
# 1089 Complete
# 1090 Complete
# 1091 Complete
# 1092 Complete
# 1093 Complete
# 1094 Incomplete
# 1095 Complete
# 1096 Complete
# 1097 Complete
# 1098 Complete
# 1099 Complete
# 1100 Incomplete
# 1101 Incomplete
# 1102 Complete
# 1103 Incomplete
# 1104 Complete
# 1105 Incomplete
# 1106 Complete
# 1107 Complete
# 1108 Complete
# 1109 Complete
# 1110 Complete
# 1111 Complete
# 1112 NA
# 1113 Incomplete
# 1114 Complete

# %% [markdown]
# ## Number of incomplete and complete responses among LGBTQ providers

# %%
table(LGBTQ_providers$Q819)
# Out:
#   Complete Incomplete
#        754        269

# %% [markdown]
# ## Descriptive Statistics for LGBTQ providers

# %% [markdown]
# ### Age counts among LGBTQ providers

# %%
## LGBTQ providers - Age
age_LGBTQ <- table(LGBTQ_providers$Q162)
age_LGBTQ
# Out:
#                 18-24                 25-34                 35-44
#                    31                   196                   241
#                 45-54                 55-64                    65
#                   243                   202                    88
# Prefer not to respond
#                    19

# %% [markdown]
# ### Age percentages among LGBTQ providers

# %%
age_perc_LGBTQ <- prop.table(age_LGBTQ)*100
age_perc_LGBTQ
# Out:
#                 18-24                 25-34                 35-44
#              3.039216             19.215686             23.627451
#                 45-54                 55-64                    65
#             23.823529             19.803922              8.627451
# Prefer not to respond
#              1.862745

# %% [markdown]
# ### Gender counts among LGBTQ providers

# %%
## LGBTQ providers - Gender
gender_LGBTQ <- table(LGBTQ_providers$Q157)
gender_LGBTQ
# Out:
#                                 Female/Woman
#                                          625
# Genderqueer/gender non-confirming/non-binary
#                                           65
#                                     Male/Man
#                                          271
#                        Prefer not to respond
#                                           17
#                      Prefer to self-describe
#                                            9
#                              Transgender man
#                                           19
#                            Transgender woman
#                                           14

# %% [markdown]
# ### Gender percentages among LGBTQ providers

# %%
gender_perc_LGBTQ <- prop.table(gender_LGBTQ)*100
gender_perc_LGBTQ
# Out:
#                                 Female/Woman
#                                   61.2745098
# Genderqueer/gender non-confirming/non-binary
#                                    6.3725490
#                                     Male/Man
#                                   26.5686275
#                        Prefer not to respond
#                                    1.6666667
#                      Prefer to self-describe
#                                    0.8823529
#                              Transgender man
#                                    1.8627451
#                            Transgender woman
#                                    1.3725490

# %% [markdown]
# ### Race counts among LGBTQ providers

# %%
## LGBTQ providers - Race
race_LGBTQ <- table(LGBTQ_providers$Q159)
race_LGBTQ
# Out:
#         Asian and/or Asian American           Black or African American
#                                  25                                 251
#                         Multiracial    Native American or Alaska Native
#                                  73                                  11
# Native Hawaiian or Pacific Islander               Prefer not to respond
#                                   5                                  53
#             Prefer to self-describe                  White or Caucasian
#                                  24                                 577

# %% [markdown]
# ### Race percentages among LGBTQ providers

# %%
race_perc_LGBTQ <- prop.table(race_LGBTQ)*100
race_perc_LGBTQ
# Out:
#         Asian and/or Asian American           Black or African American
#                           2.4533857                          24.6319921
#                         Multiracial    Native American or Alaska Native
#                           7.1638862                           1.0794897
# Native Hawaiian or Pacific Islander               Prefer not to respond
#                           0.4906771                           5.2011776
#             Prefer to self-describe                  White or Caucasian
#                           2.3552502                          56.6241413

# %% [markdown]
# ### Hispanic/Latinx percentages among LGBTQ providers

# %%
## LGBTQ providers - Hispanic/Latinx
hisp_LGBTQ <- table(LGBTQ_providers$Q161)
hisp_LGBTQ
# Out:
#                    No Prefer not to respond                   Yes
#                   814                    19                   187

# %% [markdown]
# ### Hispanic/Latinx percentages among LGBTQ providers

# %%
hisp_perc_LGBTQ <- prop.table(hisp_LGBTQ)*100
hisp_perc_LGBTQ
# Out:
#                    No Prefer not to respond                   Yes
#             79.803922              1.862745             18.333333

# %% [markdown]
# ### Role counts among LGBTQ providers

# %%
role_counts_LGBTQ <- table(LGBTQ_providers$Q66)
role_counts_LGBTQ
# Out:
#                              Dentist      Disease Intervention Specialist
#                                    2                                    1
#      Licensed Clinical Social Worker             Licensed Practical Nurse
#                                   39                                    7
#                    Medical Assistant           Mental Health Case Manager
#                                   10                                    3
#              Mental Health Counselor           Mental Health Professional
#                                    1                                   11
#          Mental Health Professional                         Nurse Manager
#                                    1                                   17
#                        Nurse Midwife                   Nurse Practitioner
#                                    1                                   68
# Other Provider/Clinical professional                           Pharmacist
#                                    7                                   15
#                  Pharmacy Technician                         Phlebotomist
#                                    3                                    2
#                            Physician                  Physician Assistant
#                                   52                                   11
#                         Psychologist                     Registered Nurse
#                                   14                                   70

# %% [markdown]
# ### Role percentages among LGBTQ providers

# %%
role_perc_LGBTQ <- prop.table(role_counts_LGBTQ)*100
role_perc_LGBTQ
# Out:
#                              Dentist      Disease Intervention Specialist
#                            0.5970149                            0.2985075
#      Licensed Clinical Social Worker             Licensed Practical Nurse
#                           11.6417910                            2.0895522
#                    Medical Assistant           Mental Health Case Manager
#                            2.9850746                            0.8955224
#              Mental Health Counselor           Mental Health Professional
#                            0.2985075                            3.2835821
#          Mental Health Professional                         Nurse Manager
#                            0.2985075                            5.0746269
#                        Nurse Midwife                   Nurse Practitioner
#                            0.2985075                           20.2985075
# Other Provider/Clinical professional                           Pharmacist
#                            2.0895522                            4.4776119
#                  Pharmacy Technician                         Phlebotomist
#                            0.8955224                            0.5970149
#                            Physician                  Physician Assistant
#                           15.5223881                            3.2835821
#                         Psychologist                     Registered Nurse
#                            4.1791045                           20.8955224

# %% [markdown]
# ### Prescriber counts among LGBTQ providers

# %%
prescriber_counts_LGBTQ <- table(LGBTQ_providers$Q70)
prescriber_counts_LGBTQ
# Out:
#  No Yes
# 193 146

# %% [markdown]
# ### Prescriber percentages among LGBTQ providers

# %%
prescriber_perc_LGBTQ <- prop.table(prescriber_counts_LGBTQ)*100
prescriber_perc_LGBTQ
# Out:
#       No      Yes
# 56.93215 43.06785

# %% [markdown]
# ## HIV training statistcis for LGBTQ providers

# %%
# LGBTQ providers - Create a vector of column names representing the HIV topics columns
hiv_topics_LGBTQ <- c("Q198", "Q199", "Q200", "Q201", "Q202","Q203","Q204","Q205","Q206","Q207","Q208","Q209","Q210a","Q210b")

# %% [markdown]
# ### HIV topic with greatest number of 1st rankings among LGBTQ providers

# %%
# LGBTQ providers - Calculate the counts of 1st rankings for each HIV topic
hiv1_count_LGBTQ <- sapply(hiv_topics_LGBTQ, function(topic) sum(LGBTQ_providers[[topic]] == 1, na.rm = TRUE))
hiv1_count_LGBTQ
# Out:
#  Q198  Q199  Q200  Q201  Q202  Q203  Q204  Q205  Q206  Q207  Q208  Q209 Q210a
#   178    80    72    17    21    37    34    49    48     6    12    12     3
# Q210b
#     1

# %%
# LGBTQ providers - Find the HIV topic with the highest count of 1st rankings
hiv1_rank_LGBTQ <- hiv_topics_LGBTQ[which.max(hiv1_count_LGBTQ)]
hiv1_rank_LGBTQ
# Out:
# [1] "Q198"

# %%
# LGBTQ providers - Calculate the percentage of 1st rankings
hiv1_perc_LGBTQ <- (hiv1_count_LGBTQ[which.max(hiv1_count_LGBTQ)] / sum(rowSums(!is.na(LGBTQ_providers[, hiv_topics_LGBTQ])) > 0)) * 100
hiv1_perc_LGBTQ
# Out:
#     Q198
# 30.95652

# %% [markdown]
# ### HIV topic with greatest number of 2nd rankings among LGBTQ providers

# %%
# LGBTQ providers - Calculate the counts of 2nd rankings for each HIV topic
hiv2_count_LGBTQ <- sapply(hiv_topics_LGBTQ, function(topic) sum(LGBTQ_providers[[topic]] == 2, na.rm = TRUE))
hiv2_count_LGBTQ
# Out:
#  Q198  Q199  Q200  Q201  Q202  Q203  Q204  Q205  Q206  Q207  Q208  Q209 Q210a
#    56    87    76    26    42    51    48    49    56    15    19     2     0
# Q210b
#     1

# %%
# LGBTQ providers - Find the HIV topic with the highest count of 2nd rankings
hiv2_rank_LGBTQ <- hiv_topics_LGBTQ[which.max(hiv2_count_LGBTQ)]
hiv2_rank_LGBTQ
# Out:
# [1] "Q199"

# %%
# LGBTQ providers - Calculate the percentage of 2nd rankings
hiv2_perc_LGBTQ  <- (hiv2_count_LGBTQ[which.max(hiv2_count_LGBTQ)] / sum(rowSums(!is.na(LGBTQ_providers[, hiv_topics_LGBTQ])) > 0)) * 100
hiv2_perc_LGBTQ
# Out:
#     Q199
# 15.13043

# %% [markdown]
# ### HIV topic with greatest number of 3rd rankings among LGBTQ providers

# %%
# LGBTQ providers - Calculate the counts of 3rd rankings for each HIV topic
hiv3_count_LGBTQ  <- sapply(hiv_topics_LGBTQ, function(topic) sum(LGBTQ_providers[[topic]] == 3, na.rm = TRUE))
hiv3_count_LGBTQ
# Out:
#  Q198  Q199  Q200  Q201  Q202  Q203  Q204  Q205  Q206  Q207  Q208  Q209 Q210a
#    65    47    53    17    56    46    57    58    52    12    36    16     2
# Q210b
#     3

# %%
# LGBTQ providers - Find the PrEP topic with the highest count of 3rd rankings
hiv3_rank_LGBTQ <- hiv_topics_LGBTQ[which.max(hiv3_count_LGBTQ)]
hiv3_rank_LGBTQ
# Out:
# [1] "Q198"

# %%
# LGBTQ providers - Calculate the percentage of 3rd ranking
hiv3_perc_LGBTQ <- (hiv3_count_LGBTQ[which.max(hiv3_count_LGBTQ)] / sum(rowSums(!is.na(LGBTQ_providers[, hiv_topics_LGBTQ])) > 0)) * 100
hiv3_perc_LGBTQ
# Out:
#     Q198
# 11.30435

# %% [markdown]
# ### Top 3 HIV topics among LGBTQ providers

# %%
# Calculate the counts for each HIV topic
topic_counts_LGBTQ <- sapply(hiv_topics_LGBTQ, function(topic) sum(LGBTQ_providers[[topic]] %in% c(1, 2, 3), na.rm = TRUE))

# Sort the topics based on their counts in descending order
sorted_topics_LGBTQ <- sort(topic_counts_LGBTQ, decreasing = TRUE)

# Get the top 3 topics
top_3_topics_LGBTQ <- names(sorted_topics_LGBTQ)[1:3]

top_3_topics_LGBTQ
# Out:
# [1] "Q198" "Q199" "Q200"

# %% [markdown]
# ## PrEP training statistcis for LGBTQ providers

# %%
# LGBTQ providers - Create a vector of column names representing the PrEP topics columns
prep_topics_LGBTQ <- c("Q211", "Q212", "Q213", "Q214", "Q215","Q216","Q217","Q218","Q219","Q220","Q221","Q222","Q223","Q224","Q225")

# %% [markdown]
# ### PrEP topic with greatest number of 1st rankings among LGBTQ providers

# %%
# LGBTQ providers - Calculate the counts of 1st rankings for each PrEP topic
prep1_count_LGBTQ <- sapply(prep_topics_LGBTQ, function(topic) sum(LGBTQ_providers[[topic]] == 1, na.rm = TRUE))
prep1_count_LGBTQ
# Out:
# Q211 Q212 Q213 Q214 Q215 Q216 Q217 Q218 Q219 Q220 Q221 Q222 Q223 Q224 Q225
#  124   73   62  108   11   22   20   48   37   31   19   29   36   12    3

# %%
# LGBTQ providers - Find the PrEP topic with the highest count of 1st rankings
prep1_rank_LGBTQ <- prep_topics_LGBTQ[which.max(prep1_count_LGBTQ)]
prep1_rank_LGBTQ
# Out:
# [1] "Q211"

# %%
# LGBTQ providers - Calculate the percentage of 1st rankings
prep1_perc_LGBTQ <- (prep1_count_LGBTQ[which.max(prep1_count_LGBTQ)] / sum(rowSums(!is.na(LGBTQ_providers[, prep_topics_LGBTQ])) > 0)) * 100
prep1_perc_LGBTQ
# Out:
#    Q211
# 19.2846

# %% [markdown]
# ### PrEP topic with greatest number of 2nd rankings among LGBTQ providers

# %%
# LGBTQ providers - Calculate the counts of 2nd rankings for each PrEP topic
prep2_count_LGBTQ <- sapply(prep_topics_LGBTQ, function(topic) sum(LGBTQ_providers[[topic]] == 2, na.rm = TRUE))
prep2_count_LGBTQ
# Out:
# Q211 Q212 Q213 Q214 Q215 Q216 Q217 Q218 Q219 Q220 Q221 Q222 Q223 Q224 Q225
#   29   70   53   80   26   34   37   77   50   39   24   27   41   15    0

# %%
# LGBTQ providers - Find the PrEP topic with the highest count of 2nd rankings
prep2_rank_LGBTQ <- prep_topics_LGBTQ[which.max(prep2_count_LGBTQ)]
prep2_rank_LGBTQ
# Out:
# [1] "Q214"

# %%
# LGBTQ providers - Calculate the percentage of 2nd rankings
prep2_perc_LGBTQ  <- (prep2_count_LGBTQ[which.max(prep2_count_LGBTQ)] / sum(rowSums(!is.na(LGBTQ_providers[, prep_topics_LGBTQ])) > 0)) * 100
prep2_perc_LGBTQ
# Out:
#     Q214
# 12.44168

# %% [markdown]
# ### PrEP topic with greatest number of 3rd rankings among LGBTQ providers

# %%
# LGBTQ providers - Calculate the counts of 3rd rankings for each PrEP topic
prep3_count_LGBTQ  <- sapply(prep_topics_LGBTQ, function(topic) sum(LGBTQ_providers[[topic]] == 3, na.rm = TRUE))
prep3_count_LGBTQ
# Out:
# Q211 Q212 Q213 Q214 Q215 Q216 Q217 Q218 Q219 Q220 Q221 Q222 Q223 Q224 Q225
#   44   21   43   52   18   35   38   69   26   66   42   46   42   41    5

# %%
# LGBTQ providers - Find the PrEP topic with the highest count of 3rd rankings
prep3_rank_LGBTQ <- prep_topics_LGBTQ[which.max(prep3_count_LGBTQ )]
prep3_rank_LGBTQ
# Out:
# [1] "Q218"

# %%
# LGBTQ providers - Calculate the percentage of 3rd ranking
prep3_perc_LGBTQ <- (prep3_count_LGBTQ[which.max(prep3_count_LGBTQ)] / sum(rowSums(!is.na(LGBTQ_providers[, prep_topics_LGBTQ])) > 0)) * 100
prep3_perc_LGBTQ
# Out:
#     Q218
# 10.73095

# %% [markdown]
# ### Top 3 PrEP topics among LGBTQ providers

# %%
# Calculate the counts for each PrEP topic
topic_counts_LGBTQ <- sapply(prep_topics_LGBTQ, function(topic) sum(LGBTQ_providers[[topic]] %in% c(1, 2, 3), na.rm = TRUE)) 

# Sort the topics based on their counts in descending order
sorted_topics_LGBTQ <- sort(topic_counts_LGBTQ, decreasing = TRUE)

# Get the top 3 topics
top_3_topics_LGBTQ <- names(sorted_topics_LGBTQ)[1:3]

top_3_topics_LGBTQ
# Out:
# [1] "Q214" "Q211" "Q218"
